# %% [markdown]
# # Lesson 5: Human in the Loop

# %% [markdown]
# Note: This notebook is running in a later version of langgraph that it was filmed with. The later version has a couple of key additions:
# - Additional state information is stored to memory and displayed when using `get_state()` or `get_state_history()`.
# - State is additionally stored every state transition while previously it was stored at an interrupt or at the end.
# These change the command output slightly, but are a useful addtion to the information available.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.checkpoint.sqlite import SqliteSaver
from utils import GroqChatLLM
from IPython.display import Image, display
import sqlite3
conn = sqlite3.connect("checkpoints.sqlite", check_same_thread=False)
memory = SqliteSaver(conn)
#memory = SqliteSaver.from_conn_string(":memory:")

# %%
from uuid import uuid4
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage

"""
In previous examples we've annotated the `messages` state key
with the default `operator.add` or `+` reducer, which always
appends new messages to the end of the existing messages array.

Now, to support replacing existing messages, we annotate the
`messages` key with a customer reducer function, which replaces
messages with the same `id`, and appends them otherwise.
"""
def reduce_messages(left: list[AnyMessage], right: list[AnyMessage]) -> list[AnyMessage]:
    # assign ids to messages that don't have them
    for message in right:
        if not message.id:
            message.id = str(uuid4())
    # merge the new messages with the existing messages
    merged = left.copy()
    for message in right:
        for i, existing in enumerate(merged):
            # replace any existing messages with the same id
            if existing.id == message.id:
                merged[i] = message
                break
        else:
            # append any new messages to the end
            merged.append(message)
    return merged

class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], reduce_messages]

# %%
tool = TavilySearchResults(max_results=2)

# %% [markdown]
# ## Manual human approval

# %%
class Agent:
    def __init__(self, model, tools, system="", checkpointer=None):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_llm)
        graph.add_node("action", self.take_action)
        
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")

        self.graph = graph.compile(
            checkpointer=checkpointer,
            interrupt_before=["action"]
        )
        display(Image(self.graph.get_graph().draw_mermaid_png()))
        
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_llm(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        print(state)
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
#model = ChatOpenAI(model="gpt-3.5-turbo")
model = GroqChatLLM(model_name='llama-3.1-8b-instant')
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="Whats the weather in SF?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='What is the weather in sf?'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_nes8', 'function': {'arguments': '{"query": "weather in sf"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_vvah', 'function': {'arguments': '{"query": "current weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 293, 'total_tokens': 360, 'completion_time': 0.210940495, 'prompt_time': 0.023038788, 'queue_time': 0.0008450519999999989, 'total_time': 0.233979283}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-169ae4a5-87d4-444a-9a22-699486b9bd18-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in sf'}, 'id': 'call_nes8', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in san francisco'}, 'id': 'call_vvah', 'type': 'tool_call'}], usage_metadata={'input_tokens': 293, 'output_tokens': 67, 'total_tokens': 360}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492280, \'localtime\': \'2024-09-16 06:11\'}, \'current\': {\'last_updated_epoch\': 1726491600, \'last_updated\': \'2024-09-16 06:00\', \'temp_c\': 13.9, \'temp_f\': 57.0, \'is_day\': 0, \'condition\': {\'text\': \'Partly cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 10.7, \'wind_kph\': 17.3, \'wind_degree\': 273, \'wind_dir\': \'W\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.78, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 89, \'cloud\': 75, \'feelslike_c\': 12.5, \'feelslike_f\': 54.5, \'windchill_c\': 11.7, \'windchill_f\': 53.1, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.5, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 15.1, \'gust_kph\': 24.2}}"}, {\'url\': \'https://www.meteoprog.com/weather/Sanfrancisco/month/september/\', \'content\': \'San Francisco (United States) weather in September 2024 ☀️ Accurate weather forecast for San Francisco in September ⛅ Detailed forecast By month Current temperature "near me" Weather news ⊳ Widget of weather ⊳ Water temperature | METEOPROG\'}]', name='tavily_search_results_json', tool_call_id='call_nes8'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492280, \'localtime\': \'2024-09-16 06:11\'}, \'current\': {\'last_updated_epoch\': 1726491600, \'last_updated\': \'2024-09-16 06:00\', \'temp_c\': 13.9, \'temp_f\': 57.0, \'is_day\': 0, \'condition\': {\'text\': \'Partly cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 10.7, \'wind_kph\': 17.3, \'wind_degree\': 273, \'wind_dir\': \'W\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.78, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 89, \'cloud\': 75, \'feelslike_c\': 12.5, \'feelslike_f\': 54.5, \'windchill_c\': 11.7, \'windchill_f\': 53.1, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.5, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 15.1, \'gust_kph\': 24.2}}"}, {\'url\': \'https://www.timeanddate.com/weather/@z-us-94134/ext\', \'content\': \'Forecasted weather conditions the coming 2 weeks for San Francisco. Sign in. News. News Home; Astronomy News; Time Zone News ... 16 pm: Mon Sep 16: 68 / 59 °F ... 6: ...
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_nkqr', 'function': {'arguments': '{"query": "weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 8049, 'total_tokens': 8071, 'completion_time': 0.029333333, 'prompt_time': 1.67612209, 'queue_time': 0.030606365999999996, 'total_time': 1.705455423}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_9cb648b966', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-25919bf4-cf26-4467-bee5-2f32df978e44-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in san francisco'}, 'id': 'call_nkqr', 'type': 'tool_call'}], usage_metadata={'input_tokens': 8049, 'output_tokens': 22, 'total_tokens': 8071})]}

# %%
print(abot.graph.get_state(thread))
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in sf?'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_nes8', 'function': {'arguments': '{"query": "weather in sf"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_vvah', 'function': {'arguments': '{"query": "current weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 293, 'total_tokens': 360, 'completion_time': 0.210940495, 'prompt_time': 0.023038788, 'queue_time': 0.0008450519999999989, 'total_time': 0.233979283}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-169ae4a5-87d4-444a-9a22-699486b9bd18-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in sf'}, 'id': 'call_nes8', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in san francisco'}, 'id': 'call_vvah', 'type': 'tool_call'}], usage_metadata={'input_tokens': 293, 'output_tokens': 67, 'total_tokens': 360}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492280, \'localtime\': \'2024-09-16 06:11\'}, \'current\': {\'last_updated_epoch\': 1726491600, \'last_updated\': \'2024-09-16 06:00\', \'temp_c\': 13.9, \'temp_f\': 57.0, \'is_day\': 0, \'condition\': {\'text\': \'Partly cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 10.7, \'wind_kph\': 17.3, \'wind_degree\': 273, \'wind_dir\': \'W\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.78, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 89, \'cloud\': 75, \'feelslike_c\': 12.5, \'feelslike_f\': 54.5, \'windchill_c\': 11.7, \'windchill_f\': 53.1, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.5, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 15.1, \'gust_kph\': 24.2}}"}, {\'url\': \'https://www.meteoprog.com/weather/Sanfrancisco/month/september/\', \'content\': \'San Francisco (United States) weather in September 2024 ☀️ Accurate weather forecast for San Francisco in September ⛅ Detailed forecast By month Current temperature "near me" Weather news ⊳ Widget of weather ⊳ Water temperature | METEOPROG\'}]', name='tavily_search_results_json', tool_call_id='call_nes8'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492280, \'localtime\': \'2024-09-16 06:11\'}, \'current\': {\'last_updated_epoch\': 1726491600, \'last_updated\': \'2024-09-16 06:00\', \'temp_c\': 13.9, \'temp_f\': 57.0, \'is_day\': 0, \'condition\': {\'text\': \'Partly cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 10.7, \'wind_kph\': 17.3, \'wind_degree\': 273, \'wind_dir\': \'W\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.78, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 89, \'cloud\': 75, \'feelslike_c\': 12.5, \'feelslike_f\': 54.5, \'windchill_c\': 11.7, \'windchill_f\': 53.1, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.5, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 15.1, \'gust_kph\': 24.2}}"}, {\'url\': \'https://www.timeanddate.com/weather/@z-us-94134/ext\', \'content\': \'Forecasted weather conditions the coming 2 weeks for San Francisco. Sign in. News. News Home; Astronomy News; Time Zone News ... 16 pm: Mon Sep  ...

# %%
abot.graph.get_state(thread).next
# Out:
# ('action',)

# %% [markdown]
# ### continue after interrupt

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in san francisco'}, 'id': 'call_nkqr', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726500181, \'localtime\': \'2024-09-16 08:23\'}, \'current\': {\'last_updated_epoch\': 1726499700, \'last_updated\': \'2024-09-16 08:15\', \'temp_c\': 14.4, \'temp_f\': 57.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 5.8, \'wind_kph\': 9.4, \'wind_degree\': 276, \'wind_dir\': \'W\', \'pressure_mb\': 1010.0, \'pressure_in\': 29.82, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 87, \'cloud\': 100, \'feelslike_c\': 14.0, \'feelslike_f\': 57.1, \'windchill_c\': 12.7, \'windchill_f\': 54.8, \'heatindex_c\': 13.0, \'heatindex_f\': 55.3, \'dewpoint_c\': 12.1, \'dewpoint_f\': 53.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 3.0, \'gust_mph\': 8.0, \'gust_kph\': 12.9}}"}, {\'url\': \'https://www.weathertab.com/en/c/e/09/united-states/california/san-francisco/\', \'content\': \'Explore comprehensive September 2024 weather forecasts for San Francisco, including daily high and low temperatures, precipitation risks, and monthly temperature trends. Featuring detailed day-by-day forecasts, dynamic graphs of daily rain probabilities, and temperature trends to help you plan ahead.\'}]', name='tavily_search_results_json', tool_call_id='call_nkqr')]}
# {'messages': [HumanMessage(content='What is the weather in sf?'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_nes8', 'function': {'arguments': '{"query": "weather in sf"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_vvah', 'function': {'arguments': '{"query": "current weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 293, 'total_tokens': 360, 'completion_time': 0.210940495, 'prompt_time': 0.023038788, 'queue_time': 0.0008450519999999989, 'total_time': 0.233979283}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-169ae4a5-87d4-444a-9a22-699486b9bd18-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in sf'}, 'id': 'call_nes8', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in san francisco'}, 'id': 'call_vvah', 'type': 'tool_call'}], usage_metadata={'input_tokens': 293, 'output_tokens': 67, 'total_tokens': 360}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492280, \'localtime\': \'2024-09-16 06:11\'}, \'current\': {\'last_updated_epoch\': 1726491600, \'last_updated\': \'2024-09-16 06:00\', \'temp_c\': 13.9, \'temp_f\': 57.0, \'is_day\': 0, \'condition\': {\'text\': \'Partly cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 10.7, \'wind_kph\': 17.3, \'wind_degree\': 273, \'wind_dir\': \'W\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.78, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 89, \'cloud\': 75, \'feelslike_c\': 12.5, \'feelslike_f\': 54.5, \'windchill_c\': 11.7, \'windchill_f\': 53.1, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.5, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 15.1, \'gust_kph\': 24.2}}"}, {\'url\': \'https://www.meteoprog.com/weather/Sanfrancisco/month/september/\', \'content\': \'San Francisco (United States) weather in September 2024 ☀️ Accurate weather forecast for San Francisco in September ⛅ Detailed forecast By month Current temperature "near me" Weather news ⊳ Widget of weather ⊳ Water temperature | METEOPROG\'}]', name='tavily_search_results_json', tool_call_id='call_nes8'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492280, \'localtime\': \'2024-09-16 06:11\'}, \'current\': {\'last_updated_epoch\': 1726491600, \'last_updated\': \'2024-09-16 06:00\', \'temp_c\': 13.9, \'temp_f\': 57.0, \'is_day\': 0, \'condition\': {\'text\': \'Partly cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 10.7, \'wind_kph\': 17.3, \'wind_degree\': 273, \'wind_dir\': \'W\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.78, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 89, \'cloud\': 75, \'feelslike_c\': 12.5, \'feelslike_f\': 54.5, \'windchill_c\': 11.7, \'windchill_f\': 53.1, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.5, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 15.1, \'gust_kph\': 24.2}}"}, {\'url\': \'https://www.timeanddate.com/weather/@z-us-94134/ext\', \'content\': \'Forecasted weather conditions the coming 2 weeks for San Francisco. Sign in. News. News Home; Astronomy News; Time Zone News ... 16 pm: Mon Sep 16: 68 / 59 °F ... 6: ...
# {'messages': [AIMessage(content='The current weather in San Francisco is overcast with a temperature of 14.4°C (57.9°F). The wind is coming from the west at 5.8 mph (9.4 kph). The humidity is at 87%, and the pressure is 1010.0 hPa (29.82 in). For the month of September, the forecast shows mostly sunny conditions with temperatures ranging from 53.8°F (12.1°C) to 70°F (21.1°C).', response_metadata={'token_usage': {'completion_tokens': 105, 'prompt_tokens': 8571, 'total_tokens': 8676, 'completion_time': 0.14, 'prompt_time': 1.82839769, 'queue_time': 0.0037005679999999597, 'total_time': 1.96839769}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f66ccb39ec', 'finish_reason': 'stop', 'logprobs': None}, id='run-207d1ac9-4f62-425d-8606-89225515572d-0', usage_metadata={'input_tokens': 8571, 'output_tokens': 105, 'total_tokens': 8676})]}

# %%
print(abot.graph.get_state(thread))
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='What is the weather in sf?'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_nes8', 'function': {'arguments': '{"query": "weather in sf"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_vvah', 'function': {'arguments': '{"query": "current weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 293, 'total_tokens': 360, 'completion_time': 0.210940495, 'prompt_time': 0.023038788, 'queue_time': 0.0008450519999999989, 'total_time': 0.233979283}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-169ae4a5-87d4-444a-9a22-699486b9bd18-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in sf'}, 'id': 'call_nes8', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in san francisco'}, 'id': 'call_vvah', 'type': 'tool_call'}], usage_metadata={'input_tokens': 293, 'output_tokens': 67, 'total_tokens': 360}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492280, \'localtime\': \'2024-09-16 06:11\'}, \'current\': {\'last_updated_epoch\': 1726491600, \'last_updated\': \'2024-09-16 06:00\', \'temp_c\': 13.9, \'temp_f\': 57.0, \'is_day\': 0, \'condition\': {\'text\': \'Partly cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 10.7, \'wind_kph\': 17.3, \'wind_degree\': 273, \'wind_dir\': \'W\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.78, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 89, \'cloud\': 75, \'feelslike_c\': 12.5, \'feelslike_f\': 54.5, \'windchill_c\': 11.7, \'windchill_f\': 53.1, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.5, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 15.1, \'gust_kph\': 24.2}}"}, {\'url\': \'https://www.meteoprog.com/weather/Sanfrancisco/month/september/\', \'content\': \'San Francisco (United States) weather in September 2024 ☀️ Accurate weather forecast for San Francisco in September ⛅ Detailed forecast By month Current temperature "near me" Weather news ⊳ Widget of weather ⊳ Water temperature | METEOPROG\'}]', name='tavily_search_results_json', tool_call_id='call_nes8'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492280, \'localtime\': \'2024-09-16 06:11\'}, \'current\': {\'last_updated_epoch\': 1726491600, \'last_updated\': \'2024-09-16 06:00\', \'temp_c\': 13.9, \'temp_f\': 57.0, \'is_day\': 0, \'condition\': {\'text\': \'Partly cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 10.7, \'wind_kph\': 17.3, \'wind_degree\': 273, \'wind_dir\': \'W\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.78, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 89, \'cloud\': 75, \'feelslike_c\': 12.5, \'feelslike_f\': 54.5, \'windchill_c\': 11.7, \'windchill_f\': 53.1, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.5, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 15.1, \'gust_kph\': 24.2}}"}, {\'url\': \'https://www.timeanddate.com/weather/@z-us-94134/ext\', \'content\': \'Forecasted weather conditions the coming 2 weeks for San Francisco. Sign in. News. News Home; Astronomy News; Time Zone News ... 16 pm: Mon Sep  ...

# %%
abot.graph.get_state(thread).next
# Out:
# ()

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "2"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)

while abot.graph.get_state(thread).next:
    print("\n", abot.graph.get_state(thread),"\n")
    _input = input("proceed?")
    if _input != "y":
        print("aborting")
        break
    for event in abot.graph.stream(None, thread):
        for v in event.values():
            print(v)
# Out:
# {'messages': [HumanMessage(content='Which one is warmer?'), AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 291, 'total_tokens': 323, 'completion_time': 0.099687088, 'prompt_time': 0.020902289, 'queue_time': 0.0021976730000000007, 'total_time': 0.120589377}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-16ceb2b4-adcf-4940-88ca-f7d11d7bb3c3-0', usage_metadata={'input_tokens': 291, 'output_tokens': 32, 'total_tokens': 323}), HumanMessage(content='Which one is warmer?'), AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 337, 'total_tokens': 369, 'completion_time': 0.100450274, 'prompt_time': 0.026465486, 'queue_time': 0.0008678600000000015, 'total_time': 0.12691576}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-bfa5a169-f99a-4c2b-b4c1-6a17218b32ca-0', usage_metadata={'input_tokens': 337, 'output_tokens': 32, 'total_tokens': 369}), HumanMessage(content='Which one is warmer?'), AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 383, 'total_tokens': 415, 'completion_time': 0.09948559, 'prompt_time': 0.026645538, 'queue_time': 0.0011054020000000019, 'total_time': 0.126131128}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b249a32-2fd6-48fe-bc60-906d85e1f99a-0', usage_metadata={'input_tokens': 383, 'output_tokens': 32, 'total_tokens': 415}), HumanMessage(content='Whats the weather in LA?', id='a37c7c50-d6ff-4c5f-b146-7745a5de6b92'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_s6dg', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_x8rc', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 430, 'total_tokens': 496, 'completion_time': 0.207487056, 'prompt_time': 0.032166142, 'queue_time': 0.0008985879999999988, 'total_time': 0.239653198}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-83f2d5ea-e6c6-402e-9526-6248a83dfae2-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_s6dg', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_x8rc', 'type': 'tool_call'}], usage_metadata={'input_tokens': 430, 'output_tokens': 66, 'total_tokens': 496}), HumanMessage(content='Whats the weather in LA?', id='c02b7c98-7697-4d0e-9c95-22eba2351dee'), HumanMessage(content='Whats the weather in LA?', id='ecca7563-942e-4196-89b0-96a3b3091de1'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_0hx2', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_5j2e', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 512, 'total_tokens': 578, 'completion_time': 0.208016542, 'prompt_time': 0.035994171,  ...
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_smm9', 'function': {'arguments': '{"query": "Los Angeles weather today"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 1792, 'total_tokens': 1813, 'completion_time': 0.028, 'prompt_time': 0.38218156, 'queue_time': 0.002425978000000051, 'total_time': 0.41018156}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_9cb648b966', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-cbbcf09d-caae-475e-bd18-412e1091c1fa-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Los Angeles weather today'}, 'id': 'call_smm9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1792, 'output_tokens': 21, 'total_tokens': 1813})]}
#
#  StateSnapshot(values={'messages': [HumanMessage(content='Which one is warmer?'), AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 291, 'total_tokens': 323, 'completion_time': 0.099687088, 'prompt_time': 0.020902289, 'queue_time': 0.0021976730000000007, 'total_time': 0.120589377}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-16ceb2b4-adcf-4940-88ca-f7d11d7bb3c3-0', usage_metadata={'input_tokens': 291, 'output_tokens': 32, 'total_tokens': 323}), HumanMessage(content='Which one is warmer?'), AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 337, 'total_tokens': 369, 'completion_time': 0.100450274, 'prompt_time': 0.026465486, 'queue_time': 0.0008678600000000015, 'total_time': 0.12691576}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-bfa5a169-f99a-4c2b-b4c1-6a17218b32ca-0', usage_metadata={'input_tokens': 337, 'output_tokens': 32, 'total_tokens': 369}), HumanMessage(content='Which one is warmer?'), AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 383, 'total_tokens': 415, 'completion_time': 0.09948559, 'prompt_time': 0.026645538, 'queue_time': 0.0011054020000000019, 'total_time': 0.126131128}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b249a32-2fd6-48fe-bc60-906d85e1f99a-0', usage_metadata={'input_tokens': 383, 'output_tokens': 32, 'total_tokens': 415}), HumanMessage(content='Whats the weather in LA?', id='a37c7c50-d6ff-4c5f-b146-7745a5de6b92'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_s6dg', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_x8rc', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 430, 'total_tokens': 496, 'completion_time': 0.207487056, 'prompt_time': 0.032166142, 'queue_time': 0.0008985879999999988, 'total_time': 0.239653198}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-83f2d5ea-e6c6-402e-9526-6248a83dfae2-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_s6dg', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_x8rc', 'type': 'tool_call'}], usage_metadata={'input_tokens': 430, 'output_tokens': 66, 'total_tokens': 496}), HumanMessage(content='Whats the weather in LA?', id='c02b7c98-7697-4d0e-9c95-22eba2351dee'), HumanMessage(content='Whats the weather in LA?', id='ecca7563-942e-4196-89b0-96a3b3091de1'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_0hx2', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_5j2e', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 512, 'total_tokens': 578, 'completion_time': 0.208016542, 'promp ...
#
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'Los Angeles weather today'}, 'id': 'call_smm9', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726500193, \'localtime\': \'2024-09-16 08:23\'}, \'current\': {\'last_updated_epoch\': 1726499700, \'last_updated\': \'2024-09-16 08:15\', \'temp_c\': 18.9, \'temp_f\': 66.0, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 6.9, \'wind_kph\': 11.2, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1012.0, \'pressure_in\': 29.87, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 78, \'cloud\': 100, \'feelslike_c\': 18.9, \'feelslike_f\': 66.0, \'windchill_c\': 17.0, \'windchill_f\': 62.6, \'heatindex_c\': 17.0, \'heatindex_f\': 62.6, \'dewpoint_c\': 14.3, \'dewpoint_f\': 57.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.0, \'gust_kph\': 12.9}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', tool_call_id='call_smm9')]}
# {'messages': [HumanMessage(content='Which one is warmer?'), AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 291, 'total_tokens': 323, 'completion_time': 0.099687088, 'prompt_time': 0.020902289, 'queue_time': 0.0021976730000000007, 'total_time': 0.120589377}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-16ceb2b4-adcf-4940-88ca-f7d11d7bb3c3-0', usage_metadata={'input_tokens': 291, 'output_tokens': 32, 'total_tokens': 323}), HumanMessage(content='Which one is warmer?'), AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 337, 'total_tokens': 369, 'completion_time': 0.100450274, 'prompt_time': 0.026465486, 'queue_time': 0.0008678600000000015, 'total_time': 0.12691576}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-bfa5a169-f99a-4c2b-b4c1-6a17218b32ca-0', usage_metadata={'input_tokens': 337, 'output_tokens': 32, 'total_tokens': 369}), HumanMessage(content='Which one is warmer?'), AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 383, 'total_tokens': 415, 'completion_time': 0.09948559, 'prompt_time': 0.026645538, 'queue_time': 0.0011054020000000019, 'total_time': 0.126131128}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b249a32-2fd6-48fe-bc60-906d85e1f99a-0', usage_metadata={'input_tokens': 383, 'output_tokens': 32, 'total_tokens': 415}), HumanMessage(content='Whats the weather in LA?', id='a37c7c50-d6ff-4c5f-b146-7745a5de6b92'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_s6dg', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_x8rc', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 430, 'total_tokens': 496, 'completion_time': 0.207487056, 'prompt_time': 0.032166142, 'queue_time': 0.0008985879999999988, 'total_time': 0.239653198}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-83f2d5ea-e6c6-402e-9526-6248a83dfae2-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_s6dg', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_x8rc', 'type': 'tool_call'}], usage_metadata={'input_tokens': 430, 'output_tokens': 66, 'total_tokens': 496}), HumanMessage(content='Whats the weather in LA?', id='c02b7c98-7697-4d0e-9c95-22eba2351dee'), HumanMessage(content='Whats the weather in LA?', id='ecca7563-942e-4196-89b0-96a3b3091de1'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_0hx2', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_5j2e', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 512, 'total_tokens': 578, 'completion_time': 0.208016542, 'prompt_time': 0.035994171,  ...
# {'messages': [AIMessage(content='The current weather in Los Angeles is overcast with a temperature of 18.9°C (66.0°F). The wind is coming from the south at 6.9 mph (11.2 kph). The humidity is at 78%, and the pressure is 1012.0 hPa (29.87 in).', response_metadata={'token_usage': {'completion_tokens': 68, 'prompt_tokens': 2398, 'total_tokens': 2466, 'completion_time': 0.090666667, 'prompt_time': 0.495498891, 'queue_time': 0.004223464999999982, 'total_time': 0.586165558}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f66ccb39ec', 'finish_reason': 'stop', 'logprobs': None}, id='run-a81987c7-53b7-4cd0-9a79-279afdf300e9-0', usage_metadata={'input_tokens': 2398, 'output_tokens': 68, 'total_tokens': 2466})]}

# %% [markdown]
# ## Modify State
# Run until the interrupt and then modify the state.

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "3"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 1 ...
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_ange', 'function': {'arguments': '{"query": "Los Angeles weather today"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 1699, 'total_tokens': 1720, 'completion_time': 0.028, 'prompt_time': 0.347010304, 'queue_time': 0.0028875409999999935, 'total_time': 0.375010304}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_9cb648b966', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-bce00efe-054a-49b7-b035-ec5d8ff29507-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Los Angeles weather today'}, 'id': 'call_ange', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1699, 'output_tokens': 21, 'total_tokens': 1720})]}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...

# %%
current_values = abot.graph.get_state(thread)

# %%
current_values.values['messages'][-1]
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_ange', 'function': {'arguments': '{"query": "Los Angeles weather today"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 1699, 'total_tokens': 1720, 'completion_time': 0.028, 'prompt_time': 0.347010304, 'queue_time': 0.0028875409999999935, 'total_time': 0.375010304}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_9cb648b966', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-bce00efe-054a-49b7-b035-ec5d8ff29507-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Los Angeles weather today'}, 'id': 'call_ange', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1699, 'output_tokens': 21, 'total_tokens': 1720})

# %%
current_values.values['messages'][-1].tool_calls
# Out:
# [{'name': 'tavily_search_results_json',
#   'args': {'query': 'Los Angeles weather today'},
#   'id': 'call_ange',
#   'type': 'tool_call'}]

# %%
_id = current_values.values['messages'][-1].tool_calls[0]['id']
print(_id)

current_values.values['messages'][-1].tool_calls = [
    {'name': 'tavily_search_results_json',
  'args': {'query': 'current weather in Louisiana'},
  'id': _id}
]
# Out:
# call_ange

# %%
abot.graph.update_state(thread, current_values.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 1 ...
# {'configurable': {'thread_id': '3',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1ef743fa-90b6-6f86-800c-2b651996bcbc'}}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_ange', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'USA United States of America\', \'lat\': 39.44, \'lon\': -91.06, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1726500210, \'localtime\': \'2024-09-16 10:23\'}, \'current\': {\'last_updated_epoch\': 1726499700, \'last_updated\': \'2024-09-16 10:15\', \'temp_c\': 24.9, \'temp_f\': 76.8, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 5.6, \'wind_kph\': 9.0, \'wind_degree\': 103, \'wind_dir\': \'ESE\', \'pressure_mb\': 1021.0, \'pressure_in\': 30.15, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 66, \'cloud\': 100, \'feelslike_c\': 26.3, \'feelslike_f\': 79.3, \'windchill_c\': 24.7, \'windchill_f\': 76.5, \'heatindex_c\': 26.1, \'heatindex_f\': 79.0, \'dewpoint_c\': 18.3, \'dewpoint_f\': 64.9, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 7.0, \'gust_mph\': 6.4, \'gust_kph\': 10.4}}"}, {\'url\': \'https://world-weather.info/forecast/usa/louisiana/september-2024/\', \'content\': \'Detailed ⚡ Louisiana Weather Forecast for September 2024 - day/night 🌡️ temperatures, precipitations - World-Weather.info. Add the current city. Search. Weather; Archive; Widgets °F. World; United States; Missouri; ... 16 +84° +70° 17 +84° +68° 18 ...\'}]', name='tavily_search_results_json', tool_call_id='call_ange')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 1 ...
# {'messages': [AIMessage(content='The current weather in Louisiana is overcast with a temperature of 24.9°C (76.8°F). The wind is coming from the east-southeast at 5.6 mph (9.0 kph). The humidity is at 66%, and the pressure is 1021.0 hPa (30.15 in).', response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 2239, 'total_tokens': 2309, 'completion_time': 0.093333333, 'prompt_time': 0.457245963, 'queue_time': 0.0032984060000000315, 'total_time': 0.550579296}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_9cb648b966', 'finish_reason': 'stop', 'logprobs': None}, id='run-27f1ea9f-a29b-47b7-a31b-97c49e45fc44-0', usage_metadata={'input_tokens': 2239, 'output_tokens': 70, 'total_tokens': 2309})]}

# %% [markdown]
# ## Time Travel

# %%
states = []
for state in abot.graph.get_state_history(thread):
    print(state)
    print('--')
    states.append(state)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='f3d35e54-18c1-4ae3-a2b4-5ab55d685df4', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496743, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 10 ...
# --
# ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_9dj5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'USA United States of America\', \'lat\': 39.44, \'lon\': -91.06, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1726496738, \'localtime\': \'2024-09-16 09:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 09:15\', \'temp_c\': 21.2, \'temp_f\': 70.2, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 4.7, \'wind_kph\': 7.6, \'wind_degree\': 100, \'wind_dir\': \'E\', \'pressure_mb\': 1021.0, \'pressure_in\': 30.14, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 85, \'cloud\': 100, \'feelslike_c\': 21.2, \'feelslike_f\': 70.2, \'windchill_c\': 23.0, \'windchill_f\': 73.4, \'heatindex_c\': 24.3, \'heatindex_f\': 75.7, \'dewpoint_c\': 17.6, \'dewpoint_f\': 63.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 5.0, \'gust_mph\': 5.7, \'gust_kph\': 9.1}}"}, {\'url\': \'https://www.cnn.com/weather/live-news/hurricane-francine-louisiana-landfall-wednesday/index.html\', \'content\': \'Francine quickly weakened to a tropical storm Wednesday evening just hours after making landfall in Louisiana as a destructive Category 2 hurricane, pelting the state with flooding rain and winds and leaving hundreds of thousands of homes and businesses without power. A flash flood warning was issued for New Orleans and the surrounding areas as radar showed thunderstorms with heavy rain in the area, hours after Hurricane Francine barreled ashore in Louisiana. Francine’s center is located about 80 miles south-southwest of Morgan City, Louisiana, but its tropical storm-force winds extend 115 miles outward from that point, according to the National Hurricane Center. The storm-battered city of New Orleans is prepared for Hurricane Francine,\\xa0which is fast approaching the Louisiana coast as a Category 1 storm, Mayor LaToya Cantrell said in a Wednesday news conference.\'}]', name='tavily_search_results_json', id='eadcdee9-e328-41be-b345-547d56b2d02b', tool_call_id='call_9dj5'), AIMessage(content='The current weather in Louisiana is overcast with a temperature of 21.2°C (70.2°F). The wind is blowing from the east at 4.7 mph (7.6 kph). There is no precipitation at the moment, and the humidity is at 85%. The pressure is 1021.0 hPa (30.14 inHg), and the cloud cover is at 100%. The dew point is 17.6°C (63.8°F), and the visibility is 16.0 km (9.0 miles). The UV index is 5.0, and the wind chill is 23.0°C (73.4°F). The heat index is 24.3°C (75.7°F).', response_metadata={'token_usage': {'completion_tokens': 156, 'prompt_tokens': 962, 'total_tokens': 1118, 'completion_time': 0.496800993, 'prompt_time': 0.068409159, 'queue_time': 0.0009735800000000017, 'total_time': 0.5 ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_9dj5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'USA United States of America\', \'lat\': 39.44, \'lon\': -91.06, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1726496738, \'localtime\': \'2024-09-16 09:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 09:15\', \'temp_c\': 21.2, \'temp_f\': 70.2, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 4.7, \'wind_kph\': 7.6, \'wind_degree\': 100, \'wind_dir\': \'E\', \'pressure_mb\': 1021.0, \'pressure_in\': 30.14, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 85, \'cloud\': 100, \'feelslike_c\': 21.2, \'feelslike_f\': 70.2, \'windchill_c\': 23.0, \'windchill_f\': 73.4, \'heatindex_c\': 24.3, \'heatindex_f\': 75.7, \'dewpoint_c\': 17.6, \'dewpoint_f\': 63.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 5.0, \'gust_mph\': 5.7, \'gust_kph\': 9.1}}"}, {\'url\': \'https://www.cnn.com/weather/live-news/hurricane-francine-louisiana-landfall-wednesday/index.html\', \'content\': \'Francine quickly weakened to a tropical storm Wednesday evening just hours after making landfall in Louisiana as a destructive Category 2 hurricane, pelting the state with flooding rain and winds and leaving hundreds of thousands of homes and businesses without power. A flash flood warning was issued for New Orleans and the surrounding areas as radar showed thunderstorms with heavy rain in the area, hours after Hurricane Francine barreled ashore in Louisiana. Francine’s center is located about 80 miles south-southwest of Morgan City, Louisiana, but its tropical storm-force winds extend 115 miles outward from that point, according to the National Hurricane Center. The storm-battered city of New Orleans is prepared for Hurricane Francine,\\xa0which is fast approaching the Louisiana coast as a Category 1 storm, Mayor LaToya Cantrell said in a Wednesday news conference.\'}]', name='tavily_search_results_json', id='eadcdee9-e328-41be-b345-547d56b2d02b', tool_call_id='call_9dj5')]}, next=('llm',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-828b-699f-8003-14458e339537'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'USA United States of America\', \'lat\': 39.44, \'lon\': -91.06, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1726496738, \'localtime\': \'2024-09-16 09:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 09:15\', \'temp_c\': 21.2, \'temp_f\': 70.2, \'is_day\': 1, \'condition\': {\'tex ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_9dj5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-5f30-6264-8002-b47ea4af1500'}}, metadata={'source': 'update', 'step': 2, 'writes': {'llm': {'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_9dj5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358})]}}, 'parents': {}}, created_at='2024-09-16T14:25:55.952888+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-5e67-67f0-8001-c18b68dfce85'}}, tasks=(PregelTask(id='263e7e05-53d2-39e0-5efb-9ba0d0999381', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None),))
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-5e67-67f0-8001-c18b68dfce85'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358})]}}, 'step': 1, 'parents': {}}, created_at='2024-09-16T14:25:55.870667+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-5204-6bf8-8000-456e2a191d53'}}, tasks=(PregelTask(id='53563ed1-55b3-56ff-c428-ef5f6acb5574', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None),))
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69')]}, next=('llm',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-5204-6bf8-8000-456e2a191d53'}}, metadata={'source': 'loop', 'writes': None, 'step': 0, 'parents': {}}, created_at='2024-09-16T14:25:54.571960+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-51fe-6f01-bfff-a95bb078247a'}}, tasks=(PregelTask(id='7567ebc8-1d5d-a71f-7e73-6fe079636dfd', name='llm', path=('__pregel_pull', 'llm'), error=None, interrupts=(), state=None),))
# --
# StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-51fe-6f01-bfff-a95bb078247a'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in LA?')]}}, 'step': -1, 'parents': {}}, created_at='2024-09-16T14:25:54.569583+00:00', parent_config=None, tasks=(PregelTask(id='743f3f32-5ee7-4256-8502-bec159dc98f8', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
# --

# %% [markdown]
# To fetch the same state as was filmed, the offset below is changed to `-3` from `-1`. This accounts for the initial state `__start__` and the first state that are now stored to state memory with the latest version of software.

# %%
to_replay = states[-3]

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-5e67-67f0-8001-c18b68dfce85'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358})]}}, 'step': 1, 'parents': {}}, created_at='2024-09-16T14:25:55.870667+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-5204-6bf8-8000-456e2a191d53'}}, tasks=(PregelTask(id='53563ed1-55b3-56ff-c428-ef5f6acb5574', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None),))

# %%
for event in abot.graph.stream(None, to_replay.config):
    for k, v in event.items():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726500237, \'localtime\': \'2024-09-16 08:23\'}, \'current\': {\'last_updated_epoch\': 1726499700, \'last_updated\': \'2024-09-16 08:15\', \'temp_c\': 18.9, \'temp_f\': 66.0, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 6.9, \'wind_kph\': 11.2, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1012.0, \'pressure_in\': 29.87, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 78, \'cloud\': 100, \'feelslike_c\': 18.9, \'feelslike_f\': 66.0, \'windchill_c\': 17.0, \'windchill_f\': 62.6, \'heatindex_c\': 17.0, \'heatindex_f\': 62.6, \'dewpoint_c\': 14.3, \'dewpoint_f\': 57.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.0, \'gust_kph\': 12.9}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726500193, \'localtime\': \'2024-09-16 08:23\'}, \'current\': {\'last_updated_epoch\': 1726499700, \'last_updated\': \'2024-09-16 08:15\', \'temp_c\': 18.9, \'temp_f\': 66.0, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 6.9, \'wind_kph\': 11.2, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1012.0, \'pressure_in\': 29.87, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 78, \'cloud\': 100, \'feelslike_c\': 18.9, \'feelslike_f\': 66.0, \'windchill_c\': 17.0, \'windchill_f\': 62.6, \'heatindex_c\': 17.0, \'heatindex_f\': 62.6, \'dewpoint_c\': 14.3, \'dewpoint_f\': 57.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.0, \'gust_kph\': 12.9}}"}, {\'url\': \'https://www.timeanddate.com/weather/@z-us-90067\', \'content\': \'Current weather in Los Angeles and forecast for today, tomorrow, and next 14 days. Sep 17-18. Sign in. News. News Home; ... Current Time: Sep 13, 2024 at 11:33:28 pm: Latest Report: Sep 13, 2024 at 10:53 pm: Visibility: 10 mi: ... 16. 71 / 59 °F. 17. 74 / 58 °F. 18. 72 / 58 °F. 19. 72 / 63 °F. 20. 76 / 59 °F. 21. 77 / 62 °F. 22.\'}]', name='tavily_search_results_json', tool_call_id='call_tbe4')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726500237, \'localtime\': \'2024-09-16 08:23\'}, \'current\': {\'last_updated_epoch\': 1726499700, \'last_updated\': \'2024-09-16 08:15\', \'temp_c\': 18.9, \'temp_f\': 66.0, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 6.9, \'wind_kph\': 11.2, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1012.0, \'pressure_in\': 29.87, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 78, \'cloud\': 100, \'feelslike_c\': 18.9, \'feelslike_f\': 66.0, \'windchill_c\': 17.0, \'windchill_f\': 62.6, \'heatindex_c\': 17.0, \'heatindex_f\': 62.6, \'dewpoint_c\': 14.3, \'dewpoint_f\': 57.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.0, \'gust_kph\': 12.9}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='d2b0c5aa-2321-4115-81bf-c193d2decbb8', tool_call_id='call_9dj5'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726500193, \'localtime\': \'2024-09-16 08:23\'}, \'current\': {\'last_updated_epoch\': 1726499700, \'last_updated\': \'2024-09-16 08:15\', \'temp_c\': 18.9, \'temp_f\': 66.0, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 6.9, \'wind_kph\': 11.2, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1012.0, \'pressure_in\': 29.87, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 78, \'cloud\': 100, \'feelslike_c\': 1 ...
# {'messages': [AIMessage(content='The current weather in LA is overcast with a temperature of 18.9°C (66.0°F) and a humidity of 78%. The wind is blowing at 11.2 km/h (6.9 mph) from the south. The visibility is 16 km (9.9 mi).', response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 1557, 'total_tokens': 1621, 'completion_time': 0.085333333, 'prompt_time': 0.318936897, 'queue_time': 0.0020530500000000007, 'total_time': 0.40427023}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f66ccb39ec', 'finish_reason': 'stop', 'logprobs': None}, id='run-b1f81ce9-234f-42a2-855d-fbac2f492a7c-0', usage_metadata={'input_tokens': 1557, 'output_tokens': 64, 'total_tokens': 1621})]}

# %% [markdown]
# ## Go back in time and edit

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-5e67-67f0-8001-c18b68dfce85'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358})]}}, 'step': 1, 'parents': {}}, created_at='2024-09-16T14:25:55.870667+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-5204-6bf8-8000-456e2a191d53'}}, tasks=(PregelTask(id='53563ed1-55b3-56ff-c428-ef5f6acb5574', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None),))

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']
to_replay.values['messages'][-1].tool_calls = [{'name': 'tavily_search_results_json',
  'args': {'query': 'current weather in LA, accuweather'},
  'id': _id}]

# %%
branch_state = abot.graph.update_state(to_replay.config, to_replay.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_9dj5'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358})]}

# %%
for event in abot.graph.stream(None, branch_state):
    for k, v in event.items():
        if k != "__end__":
            print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_9dj5', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726500253, \'localtime\': \'2024-09-16 08:24\'}, \'current\': {\'last_updated_epoch\': 1726499700, \'last_updated\': \'2024-09-16 08:15\', \'temp_c\': 18.9, \'temp_f\': 66.0, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 6.9, \'wind_kph\': 11.2, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1012.0, \'pressure_in\': 29.87, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 78, \'cloud\': 100, \'feelslike_c\': 18.9, \'feelslike_f\': 66.0, \'windchill_c\': 17.0, \'windchill_f\': 62.6, \'heatindex_c\': 17.0, \'heatindex_f\': 62.6, \'dewpoint_c\': 14.3, \'dewpoint_f\': 57.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.0, \'gust_kph\': 12.9}}"}, {\'url\': \'https://forecast.weather.gov/MapClick.php?lat=34.0906488388739&lon=-118.13592194194337\', \'content\': \'Current conditions at LOS ANGELES DOWNTOWN (FHMC1) Lat: 34.06778°NLon: 118.24167°WElev: 413.0ft. NA. 94°F. 34°C. ... 2024-6pm PDT Sep 16, 2024 . Forecast Discussion . Additional Resources. Radar & Satellite Image. Hourly Weather Forecast. National Digital Forecast Database. High Temperature. Chance of Precipitation.\'}]', name='tavily_search_results_json', tool_call_id='call_9dj5')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_9dj5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726500253, \'localtime\': \'2024-09-16 08:24\'}, \'current\': {\'last_updated_epoch\': 1726499700, \'last_updated\': \'2024-09-16 08:15\', \'temp_c\': 18.9, \'temp_f\': 66.0, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 6.9, \'wind_kph\': 11.2, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1012.0, \'pressure_in\': 29.87, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 78, \'cloud\': 100, \'feelslike_c\': 18.9, \'feelslike_f\': 66.0, \'windchill_c\': 17.0, \'windchill_f\': 62.6, \'heatindex_c\': 17.0, \'heatindex_f\': 62.6, \'dewpoint_c\': 14.3, \'dewpoint_f\': 57.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.0, \'gust_kph\': 12.9}}"}, {\'url\': \'https://forecast.weather.gov/MapClick.php?lat=34.0906488388739&lon=-118.13592194194337\', \'content\': \'Current conditions at LOS ANGELES DOWNTOWN (FHMC1) Lat: 34.06778°NLon: 118.24167°WElev: 413.0ft. NA. 94°F. 34°C. ... 2024-6pm PDT Sep 16, 2024 . Forecast Discussion . Additional Resources. Radar & Satellite Image. Hourly Weather Forecast. National Digital Forecast Database. High Temperature. Chance of Precipitation.\'}]', name='tavily_search_results_json', id='2337dcc1-9ad6-40a0-94ad-c252acd5067a', tool_call_id='call_9dj5'), AIMessage(content='The current weather in LA is overcast with a temperature of 66.0°F (18.9°C) and a wind speed of 11.2 km/h (6.9 mph) from the south.', response_metadata={'token_usage': {'completion_tokens': 45, 'prompt_tokens': 928, 'total_tokens': 973, 'completion_time': 0.06, 'prompt_time': 0.190295245, 'queue_time': 0.0027354029999999974, 'total_time': 0.250295245}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f66ccb39ec', 'finish_reason': 'stop', 'logprobs': None}, id='run-6a9f3a33-2870-4975-9426-f7762a6fd0f8-0', usage_metadata={'input_tokens': 928, 'output_tokens': 45, 'total_tokens': 973})]}
# {'messages': [AIMessage(content='The current weather in LA is overcast with a temperature of 66.0°F (18.9°C) and a wind speed of 11.2 km/h (6.9 mph) from the south.', response_metadata={'token_usage': {'completion_tokens': 45, 'prompt_tokens': 928, 'total_tokens': 973, 'completion_time': 0.06, 'prompt_time': 0.190295245, 'queue_time': 0.0027354029999999974, 'total_time': 0.250295245}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f66ccb39ec', 'finish_reason': 'stop', 'logprobs': None}, id='run-6a9f3a33-2870-4975-9426-f7762a6fd0f8-0', usage_metadata={'input_tokens': 928, 'output_tokens': 45, 'total_tokens': 973})]}

# %% [markdown]
# ## Add message to a state at a given time

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_9dj5'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-5e67-67f0-8001-c18b68dfce85'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358})]}}, 'step': 1, 'parents': {}}, created_at='2024-09-16T14:25:55.870667+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-5204-6bf8-8000-456e2a191d53'}}, tasks=(PregelTask(id='53563ed1-55b3-56ff-c428-ef5f6acb5574', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None),))

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']

# %%
state_update = {"messages": [ToolMessage(
    tool_call_id=_id,
    name="tavily_search_results_json",
    content="54 degree celcius",
)]}

# %%
branch_and_add = abot.graph.update_state(
    to_replay.config, 
    state_update, 
    as_node="action")

# %%
for event in abot.graph.stream(None, branch_and_add):
    for k, v in event.items():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='8341c1b1-e4f2-4591-9740-eabc5f9ded69'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9dj5', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_tbe4', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 292, 'total_tokens': 358, 'completion_time': 0.208266977, 'prompt_time': 0.021106852, 'queue_time': 0.0013593479999999998, 'total_time': 0.229373829}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2ba97de3-b2c2-449f-89ae-eff5e6ca0386-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_9dj5', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_tbe4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 292, 'output_tokens': 66, 'total_tokens': 358}), ToolMessage(content='54 degree celcius', name='tavily_search_results_json', id='d30a388d-04e2-4bd9-a425-9afcaf7a91e5', tool_call_id='call_9dj5'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_wpyj', 'function': {'arguments': '{"query": "54 degree celcius in fahrenheit"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 405, 'total_tokens': 430, 'completion_time': 0.033333333, 'prompt_time': 0.105546197, 'queue_time': 0.002453399000000009, 'total_time': 0.13887953}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f66ccb39ec', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-1b14175a-78c2-425a-bf0f-d4ff6d043515-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': '54 degree celcius in fahrenheit'}, 'id': 'call_wpyj', 'type': 'tool_call'}], usage_metadata={'input_tokens': 405, 'output_tokens': 25, 'total_tokens': 430})]}
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_wpyj', 'function': {'arguments': '{"query": "54 degree celcius in fahrenheit"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 405, 'total_tokens': 430, 'completion_time': 0.033333333, 'prompt_time': 0.105546197, 'queue_time': 0.002453399000000009, 'total_time': 0.13887953}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f66ccb39ec', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-1b14175a-78c2-425a-bf0f-d4ff6d043515-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': '54 degree celcius in fahrenheit'}, 'id': 'call_wpyj', 'type': 'tool_call'}], usage_metadata={'input_tokens': 405, 'output_tokens': 25, 'total_tokens': 430})]}

# %% [markdown]
# # Extra Practice

# %% [markdown]
# ## Build a small graph
# This is a small simple graph you can tinker with if you want more insight into controlling state memory.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langgraph.checkpoint.sqlite import SqliteSaver

# %% [markdown]
# Define a simple 2 node graph with the following state:
# -`lnode`: last node
# -`scratch`: a scratchpad location
# -`count` : a counter that is incremented each step

# %%
class AgentState(TypedDict):
    lnode: str
    scratch: str
    count: Annotated[int, operator.add]

# %%
def node1(state: AgentState):
    print(f"node1, count:{state['count']}")
    return {"lnode": "node_1",
            "count": 1,
           }
def node2(state: AgentState):
    print(f"node2, count:{state['count']}")
    return {"lnode": "node_2",
            "count": 1,
           }

# %% [markdown]
# The graph goes N1->N2->N1... but breaks after count reaches 3.

# %%
def should_continue(state):
    return state["count"] < 3

# %%
builder = StateGraph(AgentState)
builder.add_node("Node1", node1)
builder.add_node("Node2", node2)

builder.add_edge("Node1", "Node2")
builder.add_conditional_edges("Node2", 
                              should_continue, 
                              {True: "Node1", False: END})
builder.set_entry_point("Node1")

# %%
memory = SqliteSaver(conn)
#memory = SqliteSaver.from_conn_string(":memory:")
graph = builder.compile(checkpointer=memory)

# %% [markdown]
# ### Run it!
# Now, set the thread and run!

# %%
thread = {"configurable": {"thread_id": str(1)}}
graph.invoke({"count":0, "scratch":"hi"},thread)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# ### Look at current state

# %% [markdown]
# Get the current state. Note the `values` which are the AgentState. Note the `config` and the `thread_ts`. You will be using those to refer to snapshots below.

# %%
graph.get_state(thread)
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fe-67df-805d-48603ca684b0'}}, metadata={'source': 'loop', 'writes': {'Node2': {'lnode': 'node_2', 'count': 1}}, 'step': 93, 'parents': {}}, created_at='2024-09-16T15:27:22.516052+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fc-6ec8-805c-5cbac283a3c3'}}, tasks=())

# %% [markdown]
# View all the statesnapshots in memory. You can use the displayed `count` agentstate variable to help track what you see. Notice the most recent snapshots are returned by the iterator first. Also note that there is a handy `step` variable in the metadata that counts the number of steps in the graph execution. This is a bit detailed - but you can also notice that the *parent_config* is the *config* of the previous node. At initial startup, additional states are inserted into memory to create a parent. This is something to check when you branch or *time travel* below.

# %% [markdown]
# ### Look at state history

# %%
for state in graph.get_state_history(thread):
    print(state, "\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fe-67df-805d-48603ca684b0'}}, metadata={'source': 'loop', 'writes': {'Node2': {'lnode': 'node_2', 'count': 1}}, 'step': 93, 'parents': {}}, created_at='2024-09-16T15:27:22.516052+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fc-6ec8-805c-5cbac283a3c3'}}, tasks=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fc-6ec8-805c-5cbac283a3c3'}}, metadata={'source': 'loop', 'writes': {'Node1': {'lnode': 'node_1', 'count': 1}}, 'step': 92, 'parents': {}}, created_at='2024-09-16T15:27:22.515414+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fb-673f-805b-2378bc354b39'}}, tasks=(PregelTask(id='5360fafa-4f71-40bf-b3e5-0f018794ca7e', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fb-673f-805b-2378bc354b39'}}, metadata={'source': 'loop', 'writes': {'Node2': {'lnode': 'node_2', 'count': 1}}, 'step': 91, 'parents': {}}, created_at='2024-09-16T15:27:22.514811+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f9-6aaf-805a-df3ce8b50fa0'}}, tasks=(PregelTask(id='8795efd9-7770-5fa4-4f2b-78892772171b', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f9-6aaf-805a-df3ce8b50fa0'}}, metadata={'source': 'loop', 'writes': {'Node1': {'lnode': 'node_1', 'count': 1}}, 'step': 90, 'parents': {}}, created_at='2024-09-16T15:27:22.514081+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f6-6fd2-8059-be1a451bbfc9'}}, tasks=(PregelTask(id='8f51cbc8-288a-c8b4-01ac-12e3e10c7520', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f6-6fd2-8059-be1a451bbfc9'}}, metadata={'source': 'loop', 'writes': None, 'step': 89, 'parents': {}}, created_at='2024-09-16T15:27:22.512983+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f4-6ffd-8058-0259f0957496'}}, tasks=(PregelTask(id='1a1bfa64-59d2-4fa0-aaac-b5b1ad6cc559', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f4-6ffd-8058-0259f0957496'}}, metadata={'source': 'input', 'writes': {'__start__': {'count': 0, 'scratch': 'hi'}}, 'step': 88, 'parents': {}}, created_at='2024-09-16T15:27:22.512165+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-d461-68b6-8057-041c27a72914'}}, tasks=(PregelTask(id='1e680ccd-237d-76fa-ee2a-c07ac1f051e7', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-d461-68b6-8057-041c27a72914'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in San Francisco is overcast with a temperature of 14.4°C (57.9°F). The wind is coming from the west at 5.8 mph (9.4 kph). The humidity is at 87%, and the pressure is 1010.0 hPa (29.82 in). For the month of September, the forecast shows mostly sunny conditions with temperatures ranging from 53.8°F (12.1°C) to 70°F (21.1°C).', response_metadata={'token_usage': {'completion_tokens': 105, 'prompt_tokens': 8571, 'total_tokens': 8676, 'completion_time': 0.14, 'prompt_time': 1.82839769, 'queue_time': 0.0037005679999999597, 'total_time': 1.96839769}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f66ccb39ec', 'finish_reason': 'stop', 'logprobs': None}, id='run-207d1ac9-4f62-425d-8606-89225515572d-0', usage_metadata={'input_tokens': 8571, 'output_tokens': 105, 'total_tokens': 8676})]}}, 'step': 87, 'parents': {}}, created_at='2024-09-16T15:23:24.215244+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-b93f-6828-8056-1223f2a62fcc'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-b93f-6828-8056-1223f2a62fcc'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726500181, \'localtime\': \'2024-09-16 08:23\'}, \'current\': {\'last_updated_epoch\': 1726499700, \'last_updated\': \'2024-09-16 08:15\', \'temp_c\': 14.4, \'temp_f\': 57.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 5.8, \'wind_kph\': 9.4, \'wind_degree\': 276, \'wind_dir\': \'W\', \'pressure_mb\': 1010.0, \'pressure_in\': 29.82, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 87, \'cloud\': 100, \'feelslike_c\': 14.0, \'feelslike_f\': 57.1, \'windchill_c\': 12.7, \'windchill_f\': 54.8, \'heatindex_c\': 13.0, \'heatindex_f\': 55.3, \'dewpoint_c\': 12.1, \'dewpoint_f\': 53.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 3.0, \'gust_mph\': 8.0, \'gust_kph\': 12.9}}"}, {\'url\': \'https://www.weathertab.com/en/c/e/09/united-states/california/san-francisco/\', \'content\': \'Explore comprehensive September 2024 weather forecasts for San Francisco, including daily high and low temperatures, precipitation risks, and monthly temperature trends. Featuring detailed day-by-day forecasts, dynamic graphs of daily rain probabilities, and temperature trends to help you plan ahead.\'}]', name='tavily_search_results_json', id='2609362d-cc84-43a0-b775-056954424201', tool_call_id='call_nkqr')]}}, 'step': 86, 'parents': {}}, created_at='2024-09-16T15:23:21.370155+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-262c-6f46-8055-4eafa2e8ab56'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-262c-6f46-8055-4eafa2e8ab56'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_nkqr', 'function': {'arguments': '{"query": "weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 8049, 'total_tokens': 8071, 'completion_time': 0.029333333, 'prompt_time': 1.67612209, 'queue_time': 0.030606365999999996, 'total_time': 1.705455423}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_9cb648b966', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-25919bf4-cf26-4467-bee5-2f32df978e44-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in san francisco'}, 'id': 'call_nkqr', 'type': 'tool_call'}], usage_metadata={'input_tokens': 8049, 'output_tokens': 22, 'total_tokens': 8071})]}}, 'step': 85, 'parents': {}}, created_at='2024-09-16T15:23:05.948525+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-0cb2-6338-8054-83e70fb5254d'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-0cb2-6338-8054-83e70fb5254d'}}, metadata={'source': 'loop', 'writes': None, 'step': 84, 'parents': {}}, created_at='2024-09-16T15:23:03.276804+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-0ca4-6110-8053-947ee40770b9'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-0ca4-6110-8053-947ee40770b9'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 83, 'parents': {}}, created_at='2024-09-16T15:23:03.271012+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f6-c637-65f9-8052-ca3b40d3775d'}}, tasks=(PregelTask(id='7f72f8b4-d616-73d9-02b1-a5a344617abc', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f6-c637-65f9-8052-ca3b40d3775d'}}, metadata={'source': 'loop', 'writes': None, 'step': 82, 'parents': {}}, created_at='2024-09-16T15:22:02.199380+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f6-c62b-6411-8051-ae16b96d4fba'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f6-c62b-6411-8051-ae16b96d4fba'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 81, 'parents': {}}, created_at='2024-09-16T15:22:02.194409+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f5-9ce1-6307-8050-3d6e63700a0e'}}, tasks=(PregelTask(id='147a079e-b542-7e2b-5efc-be4499a00bda', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f5-9ce1-6307-8050-3d6e63700a0e'}}, metadata={'source': 'loop', 'writes': None, 'step': 80, 'parents': {}}, created_at='2024-09-16T15:21:31.021362+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f5-9ccf-6c48-804f-d28ae47f3214'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f5-9ccf-6c48-804f-d28ae47f3214'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 79, 'parents': {}}, created_at='2024-09-16T15:21:31.014228+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f2-7410-6327-804e-9246a23300ae'}}, tasks=(PregelTask(id='85679f1c-4f81-340f-3157-f36e4e374a2c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f2-7410-6327-804e-9246a23300ae'}}, metadata={'source': 'loop', 'writes': None, 'step': 78, 'parents': {}}, created_at='2024-09-16T15:20:06.210831+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f2-7407-6913-804d-087f3cfa7b3e'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f2-7407-6913-804d-087f3cfa7b3e'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 77, 'parents': {}}, created_at='2024-09-16T15:20:06.207291+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f1-69fb-68f8-804c-0b4fc8c3d6e9'}}, tasks=(PregelTask(id='e8bb1c0f-9508-2c4d-0ceb-fc234e175688', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f1-69fb-68f8-804c-0b4fc8c3d6e9'}}, metadata={'source': 'loop', 'writes': None, 'step': 76, 'parents': {}}, created_at='2024-09-16T15:19:38.310248+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f1-69f2-679c-804b-eb3a8c581f21'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f1-69f2-679c-804b-eb3a8c581f21'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 75, 'parents': {}}, created_at='2024-09-16T15:19:38.306531+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f0-e4f0-60ce-804a-3f8d63059d6b'}}, tasks=(PregelTask(id='d5d976d5-63d5-7b82-88c8-060176d0f88a', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f0-e4f0-60ce-804a-3f8d63059d6b'}}, metadata={'source': 'loop', 'writes': None, 'step': 74, 'parents': {}}, created_at='2024-09-16T15:19:24.359482+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f0-e4e8-6601-8049-63a7cff3649c'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f0-e4e8-6601-8049-63a7cff3649c'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 73, 'parents': {}}, created_at='2024-09-16T15:19:24.356335+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ee-e34d-6257-8048-38b9631418c2'}}, tasks=(PregelTask(id='7869446b-f34d-1253-272e-eb0029a63516', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ee-e34d-6257-8048-38b9631418c2'}}, metadata={'source': 'loop', 'writes': None, 'step': 72, 'parents': {}}, created_at='2024-09-16T15:18:30.500798+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ee-e342-607a-8047-cffab1302810'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ee-e342-607a-8047-cffab1302810'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 71, 'parents': {}}, created_at='2024-09-16T15:18:30.496242+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ec-d80c-66a3-8046-d60599ff1606'}}, tasks=(PregelTask(id='dcefa564-2153-9034-e41d-dcba9a8f5d30', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ec-d80c-66a3-8046-d60599ff1606'}}, metadata={'source': 'loop', 'writes': None, 'step': 70, 'parents': {}}, created_at='2024-09-16T15:17:35.633768+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ec-d803-6272-8045-82137705629b'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ec-d803-6272-8045-82137705629b'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 69, 'parents': {}}, created_at='2024-09-16T15:17:35.629962+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743e3-39a2-6c64-8044-5d8970f2a609'}}, tasks=(PregelTask(id='36cf838b-66bf-0ebc-d378-79bc55668ec0', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743e3-39a2-6c64-8044-5d8970f2a609'}}, metadata={'source': 'loop', 'writes': None, 'step': 68, 'parents': {}}, created_at='2024-09-16T15:13:17.431086+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743e3-399a-6c19-8043-4995676c0e66'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743e3-399a-6c19-8043-4995676c0e66'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 67, 'parents': {}}, created_at='2024-09-16T15:13:17.427797+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743df-1e18-661c-8042-2999c7394b3a'}}, tasks=(PregelTask(id='052c0f10-f04a-96a2-b9ad-6fafdb7192f5', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743df-1e18-661c-8042-2999c7394b3a'}}, metadata={'source': 'loop', 'writes': None, 'step': 66, 'parents': {}}, created_at='2024-09-16T15:11:27.169054+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743df-1e0e-609a-8041-d0193db7201c'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743df-1e0e-609a-8041-d0193db7201c'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 65, 'parents': {}}, created_at='2024-09-16T15:11:27.164813+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7439b-d318-6db4-8040-73f7dc1a38be'}}, tasks=(PregelTask(id='2facf453-9f64-7b5c-f64b-d22093b42016', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7439b-d318-6db4-8040-73f7dc1a38be'}}, metadata={'source': 'loop', 'writes': None, 'step': 64, 'parents': {}}, created_at='2024-09-16T14:41:20.787384+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7439b-d310-6ef3-803f-18459f0c6517'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7439b-d310-6ef3-803f-18459f0c6517'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 63, 'parents': {}}, created_at='2024-09-16T14:41:20.784133+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-67f9-6d1c-803e-bf1b008ccb5e'}}, tasks=(PregelTask(id='8e8e929c-9b21-05ee-45e5-26b7017fc778', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-67f9-6d1c-803e-bf1b008ccb5e'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in San Francisco is overcast with a temperature of 14.4°C (57', response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 8173, 'total_tokens': 8193, 'completion_time': 0.06058844, 'prompt_time': 0.541126708, 'queue_time': 0.002027549999999989, 'total_time': 0.601715148}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-114fb5bf-1897-4ec1-9c59-0938d53b69a3-0', usage_metadata={'input_tokens': 8173, 'output_tokens': 20, 'total_tokens': 8193})]}}, 'step': 62, 'parents': {}}, created_at='2024-09-16T14:39:22.180670+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-586c-635e-803d-f9280823d88f'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-586c-635e-803d-f9280823d88f'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726497538, \'localtime\': \'2024-09-16 07:38\'}, \'current\': {\'last_updated_epoch\': 1726497000, \'last_updated\': \'2024-09-16 07:30\', \'temp_c\': 14.4, \'temp_f\': 57.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 274, \'wind_dir\': \'W\', \'pressure_mb\': 1010.0, \'pressure_in\': 29.81, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 87, \'cloud\': 100, \'feelslike_c\': 13.4, \'feelslike_f\': 56.2, \'windchill_c\': 12.4, \'windchill_f\': 54.3, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.7, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 3.0, \'gust_mph\': 12.1, \'gust_kph\': 19.5}}"}, {\'url\': \'https://forecast.weather.gov/MapClick.php?lat=37.6188&lon=-122.3758\', \'content\': \'Current conditions at San Francisco, San Francisco International Airport (KSFO) Lat: 37.61961°NLon: ... 2024-6pm PDT Sep 16, 2024 . Forecast Discussion . Additional Resources. Radar & Satellite Image. ... National Weather Service; San Francisco Bay Area, CA; 21 Grace Hopper Ave, Stop 5; Monterey, CA 93943-5505; Comments? Questions?\'}]', name='tavily_search_results_json', id='151dc5a4-e0b0-4e3d-a8d2-914a932490b1', tool_call_id='call_xpde')]}}, 'step': 61, 'parents': {}}, created_at='2024-09-16T14:39:20.549801+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-27ad-6540-803c-e78d6bcf02c0'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-27ad-6540-803c-e78d6bcf02c0'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_xpde', 'function': {'arguments': '{"query":"weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 7583, 'total_tokens': 7616, 'completion_time': 0.102372705, 'prompt_time': 0.634856878, 'queue_time': 0.0021635369999999376, 'total_time': 0.737229583}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-e9b6d17e-688b-4fd9-92db-bf1d974b6d06-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in san francisco'}, 'id': 'call_xpde', 'type': 'tool_call'}], usage_metadata={'input_tokens': 7583, 'output_tokens': 33, 'total_tokens': 7616})]}}, 'step': 60, 'parents': {}}, created_at='2024-09-16T14:39:15.438508+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-1875-6857-803b-a043ed84440b'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-1875-6857-803b-a043ed84440b'}}, metadata={'source': 'loop', 'writes': None, 'step': 59, 'parents': {}}, created_at='2024-09-16T14:39:13.842785+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-186d-64b5-803a-127191c26462'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-186d-64b5-803a-127191c26462'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 58, 'parents': {}}, created_at='2024-09-16T14:39:13.839410+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-a724-6f14-8039-e03f2839d4c5'}}, tasks=(PregelTask(id='a0f8fb30-7151-b666-831a-92cdabfb6d55', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-a724-6f14-8039-e03f2839d4c5'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in San Francisco is overcast with a temperature of 14.4°C (57.9°F). The wind is coming from the west at 8.7 mph (14.0 kph). The humidity is at 87%, and the pressure is 1010.0 hPa (29.81 in). For the month of September, the forecast shows mostly sunny conditions with temperatures ranging from 51°F (10.6°C) to 70°F (21.1°C).', response_metadata={'token_usage': {'completion_tokens': 103, 'prompt_tokens': 7465, 'total_tokens': 7568, 'completion_time': 0.326495861, 'prompt_time': 0.797492551, 'queue_time': 0.0020620899999999054, 'total_time': 1.123988412}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-ba9e27c2-a12e-4608-a0a2-8b747077bf86-0', usage_metadata={'input_tokens': 7465, 'output_tokens': 103, 'total_tokens': 7568})]}}, 'step': 57, 'parents': {}}, created_at='2024-09-16T14:26:30.341579+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-425e-6afd-8038-440d3fed8bb6'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-425e-6afd-8038-440d3fed8bb6'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496725, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 14.4, \'temp_f\': 57.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 274, \'wind_dir\': \'W\', \'pressure_mb\': 1010.0, \'pressure_in\': 29.81, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 87, \'cloud\': 100, \'feelslike_c\': 13.4, \'feelslike_f\': 56.2, \'windchill_c\': 12.4, \'windchill_f\': 54.3, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.7, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 3.0, \'gust_mph\': 12.1, \'gust_kph\': 19.5}}"}, {\'url\': \'https://weather.com/weather/monthly/l/69bedc6a5b6e977993fb3e5344e3c06d8bc36a1fb6754c3ddfb5310a3c6d6c87\', \'content\': \'Weather.com brings you the most accurate monthly weather forecast for San Francisco, ... 16 64 ° 51 ° 17. 61 ° 52 ° 18 ... September: 70 ° 56 ° 0: October: 70 ° 54 ...\'}]', name='tavily_search_results_json', id='73629667-b63a-4de3-b797-5d4e9cd92ae8', tool_call_id='call_v8s1')]}}, 'step': 56, 'parents': {}}, created_at='2024-09-16T14:26:19.774578+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-1dba-6587-8037-39731dc2c978'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-1dba-6587-8037-39731dc2c978'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_v8s1', 'function': {'arguments': '{"query":"weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 6884, 'total_tokens': 6917, 'completion_time': 0.10212899, 'prompt_time': 0.505107015, 'queue_time': 0.0018245439999999835, 'total_time': 0.607236005}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-20ccfba2-aa9e-4517-9ec3-6d7857e3667d-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in san francisco'}, 'id': 'call_v8s1', 'type': 'tool_call'}], usage_metadata={'input_tokens': 6884, 'output_tokens': 33, 'total_tokens': 6917})]}}, 'step': 55, 'parents': {}}, created_at='2024-09-16T14:26:15.932432+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-09e4-6ea4-8036-51ae0ffd82c0'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-09e4-6ea4-8036-51ae0ffd82c0'}}, metadata={'source': 'loop', 'writes': None, 'step': 54, 'parents': {}}, created_at='2024-09-16T14:26:13.852725+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-09dd-671b-8035-ca181c79a8c5'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-09dd-671b-8035-ca181c79a8c5'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 53, 'parents': {}}, created_at='2024-09-16T14:26:13.849659+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-0fb9-6921-8034-c80720c3aa45'}}, tasks=(PregelTask(id='60a72a44-eb63-b0d7-499e-e72e2577a53f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-0fb9-6921-8034-c80720c3aa45'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in San Francisco is overcast with a temperature of 14.4°C (57.9°F). The wind is coming from the west at 8.7 mph (14.0 kph). The humidity is at 87%, and the pressure is 1010.0 hPa (29.81 in). For the next two weeks, the forecast shows mostly sunny conditions with temperatures ranging from 58°F (14.4°C) to 70°F (21.1°C).', response_metadata={'token_usage': {'completion_tokens': 103, 'prompt_tokens': 6766, 'total_tokens': 6869, 'completion_time': 0.325426963, 'prompt_time': 0.535805377, 'queue_time': 0.0019882770000000383, 'total_time': 0.86123234}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-9e33a34e-e9bf-447c-ab00-6a38fbf1c1bc-0', usage_metadata={'input_tokens': 6766, 'output_tokens': 103, 'total_tokens': 6869})]}}, 'step': 52, 'parents': {}}, created_at='2024-09-16T14:25:47.620572+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-fcf5-649e-8033-d41923fc4c24'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-fcf5-649e-8033-d41923fc4c24'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496725, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 14.4, \'temp_f\': 57.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 274, \'wind_dir\': \'W\', \'pressure_mb\': 1010.0, \'pressure_in\': 29.81, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 87, \'cloud\': 100, \'feelslike_c\': 13.4, \'feelslike_f\': 56.2, \'windchill_c\': 12.4, \'windchill_f\': 54.3, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.7, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 3.0, \'gust_mph\': 12.1, \'gust_kph\': 19.5}}"}, {\'url\': \'https://www.timeanddate.com/weather/@z-us-94134/ext\', \'content\': \'Forecasted weather conditions the coming 2 weeks for San Francisco. Sign in. News. News Home; Astronomy News; Time Zone News ... 16 pm: Mon Sep 16: 68 / 59 °F ... 6:54 am: 7:11 pm: Thu Sep 19: 70 / 58 °F: Sunny. 76 °F: 8 mph: ↑: 58%: 3%-3 (Moderate) 6:55 am: 7:10 pm * Updated Thursday, September 5, 2024 2:23:50 am San Francisco time ...\'}]', name='tavily_search_results_json', id='66273b1c-948a-4d07-9192-698dc3fb8b38', tool_call_id='call_6dhj')]}}, 'step': 51, 'parents': {}}, created_at='2024-09-16T14:25:45.652683+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-d525-6d0f-8032-e5e0af471743'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-d525-6d0f-8032-e5e0af471743'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6dhj', 'function': {'arguments': '{"query":"weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 6148, 'total_tokens': 6181, 'completion_time': 0.103653227, 'prompt_time': 0.41728126, 'queue_time': 0.0018017270000000307, 'total_time': 0.520934487}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-e6f9810b-49aa-4e4d-818a-e25e645bdaa9-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in san francisco'}, 'id': 'call_6dhj', 'type': 'tool_call'}], usage_metadata={'input_tokens': 6148, 'output_tokens': 33, 'total_tokens': 6181})]}}, 'step': 50, 'parents': {}}, created_at='2024-09-16T14:25:41.478299+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-c805-626b-8031-63e5cc3b0d15'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-c805-626b-8031-63e5cc3b0d15'}}, metadata={'source': 'loop', 'writes': None, 'step': 49, 'parents': {}}, created_at='2024-09-16T14:25:40.101782+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-c7fd-68f4-8030-c6723937c17b'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-c7fd-68f4-8030-c6723937c17b'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 48, 'parents': {}}, created_at='2024-09-16T14:25:40.098639+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-6ad4-692e-802f-09e2252636cf'}}, tasks=(PregelTask(id='69700574-9b6a-4aaa-a909-07f3f0ea2a9c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-6ad4-692e-802f-09e2252636cf'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_bkfm', 'function': {'arguments': '{"query":"weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 6102, 'total_tokens': 6135, 'completion_time': 0.102237688, 'prompt_time': 0.37884695, 'queue_time': 0.0018910799999999894, 'total_time': 0.481084638}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-20134833-0ed1-4e0a-803d-1509ec6ec338-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in san francisco'}, 'id': 'call_bkfm', 'type': 'tool_call'}], usage_metadata={'input_tokens': 6102, 'output_tokens': 33, 'total_tokens': 6135})]}}, 'step': 47, 'parents': {}}, created_at='2024-09-16T14:20:08.207583+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-5e8b-6928-802e-5dde94a5d81c'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-5e8b-6928-802e-5dde94a5d81c'}}, metadata={'source': 'loop', 'writes': None, 'step': 46, 'parents': {}}, created_at='2024-09-16T14:20:06.919388+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-5e84-6610-802d-40c2efc9b32c'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-5e84-6610-802d-40c2efc9b32c'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 45, 'parents': {}}, created_at='2024-09-16T14:20:06.916436+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74355-bc12-686c-802c-74eec471a253'}}, tasks=(PregelTask(id='e8575abf-9273-b646-b34d-8f4387deb87f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74355-bc12-686c-802c-74eec471a253'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='Los Angeles is warmer than San Francisco.', response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 6078, 'total_tokens': 6087, 'completion_time': 0.025626901, 'prompt_time': 0.38679303, 'queue_time': 0.0016302590000000228, 'total_time': 0.412419931}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-468a7f28-e5dc-4375-a598-0a6012e375ed-0', usage_metadata={'input_tokens': 6078, 'output_tokens': 9, 'total_tokens': 6087})]}}, 'step': 44, 'parents': {}}, created_at='2024-09-16T14:09:59.324812+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d342-602e-802b-04cfb497ba16'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d342-602e-802b-04cfb497ba16'}}, metadata={'source': 'loop', 'writes': None, 'step': 43, 'parents': {}}, created_at='2024-09-16T14:09:34.912496+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d33a-6fef-802a-b7c783acab9a'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d33a-6fef-802a-b7c783acab9a'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Which one is warmer?')]}}, 'step': 42, 'parents': {}}, created_at='2024-09-16T14:09:34.909619+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d30b-6b0d-8029-8ed10a11e0df'}}, tasks=(PregelTask(id='c8db5d88-506c-c73f-3500-8345e682aad9', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d30b-6b0d-8029-8ed10a11e0df'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in Los Angeles is overcast with a temperature of 18.3°C (64.9°F). The wind is coming from the south at 7.2 mph (11.5 kph). The humidity is at 81%, and the pressure is 1011.0 hPa (29.85 in). For the month of September, the forecast shows mostly sunny conditions with temperatures ranging from 64.4°F (18°C) to 82.2°F (27.9°C).', response_metadata={'token_usage': {'completion_tokens': 105, 'prompt_tokens': 5959, 'total_tokens': 6064, 'completion_time': 0.334021861, 'prompt_time': 0.391028568, 'queue_time': 0.0015205070000000043, 'total_time': 0.725050429}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-2e136a1f-2ef3-4e14-aa76-50d482c04e5a-0', usage_metadata={'input_tokens': 5959, 'output_tokens': 105, 'total_tokens': 6064})]}}, 'step': 41, 'parents': {}}, created_at='2024-09-16T14:09:34.890252+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-8115-67be-8028-1cdc347ddaf6'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-8115-67be-8028-1cdc347ddaf6'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726495746, \'localtime\': \'2024-09-16 07:09\'}, \'current\': {\'last_updated_epoch\': 1726495200, \'last_updated\': \'2024-09-16 07:00\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.weather.gov/lox/\', \'content\': \'Current Hazards. Daily Briefing; Latest Hazard Listing; Current Outlooks; ... Sep 16, 2024 at 2:04:08 am PDT Watches, Warnings & Advisories. Zoom Out. Gale Warning. Small Craft Advisory. Wind Advisory. ... National Weather Service Los Angeles, CA 520 North Elevar Street Oxnard, CA 93030 805-988-6610 Comments? Questions?\'}]', name='tavily_search_results_json', tool_call_id='call_36p3')]}}, 'step': 40, 'parents': {}}, created_at='2024-09-16T14:09:26.295942+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-5d6d-6c06-8027-3c338ab1ac71'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-5d6d-6c06-8027-3c338ab1ac71'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_36p3', 'function': {'arguments': '{"query":"weather in los angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 5387, 'total_tokens': 5420, 'completion_time': 0.104801284, 'prompt_time': 0.328606256, 'queue_time': 0.0018235289999999904, 'total_time': 0.43340754}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2f1e544e-d11a-4774-9051-fc90469bcbb3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in los angeles'}, 'id': 'call_36p3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 5387, 'output_tokens': 33, 'total_tokens': 5420})]}}, 'step': 39, 'parents': {}}, created_at='2024-09-16T14:09:22.557150+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-527d-65d3-8026-1887f62561c9'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-527d-65d3-8026-1887f62561c9'}}, metadata={'source': 'loop', 'writes': None, 'step': 38, 'parents': {}}, created_at='2024-09-16T14:09:21.410183+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-5277-642e-8025-93ee2100ce30'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-5277-642e-8025-93ee2100ce30'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='What about in la?')]}}, 'step': 37, 'parents': {}}, created_at='2024-09-16T14:09:21.407679+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-521c-612b-8024-ee29e0bd7963'}}, tasks=(PregelTask(id='83adb830-556d-6c05-52b1-0c0f9339aadc', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# ...
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dc-3340-6315-800a-2db44ebfefd2'}}, metadata={'source': 'loop', 'writes': None, 'step': 10, 'parents': {}}, created_at='2024-09-16T13:15:36.909062+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dc-333a-655c-8009-db422a2cdb75'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dc-333a-655c-8009-db422a2cdb75'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Which one is warmer?')]}}, 'step': 9, 'parents': {}}, created_at='2024-09-16T13:15:36.906665+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-fc6d-615a-8008-92bffeb449d5'}}, tasks=(PregelTask(id='95a67edd-4f47-2236-7b8c-1610c857cd2e', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-fc6d-615a-8008-92bffeb449d5'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in Los Angeles is overcast with a temperature of 18.3°C (64.9°F). The wind is coming from the southeast at 6.3 mph (10.1 kph). The humidity is at 81%, and the pressure is 1011.0 hPa (29.85 in). For the next 10 days, the forecast shows mostly sunny conditions with temperatures ranging from 20°C to 25°C.', response_metadata={'token_usage': {'completion_tokens': 93, 'prompt_tokens': 2692, 'total_tokens': 2785, 'completion_time': 0.296655938, 'prompt_time': 0.22501293, 'queue_time': 0.0015646679999999913, 'total_time': 0.521668868}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-1aafb96a-3ee5-4183-b771-57f25fc59790-0', usage_metadata={'input_tokens': 2692, 'output_tokens': 93, 'total_tokens': 2785})]}}, 'step': 8, 'parents': {}}, created_at='2024-09-16T13:15:31.160291+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-f0f2-63dc-8007-b20522ad79bf'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-f0f2-63dc-8007-b20522ad79bf'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492505, \'localtime\': \'2024-09-16 06:15\'}, \'current\': {\'last_updated_epoch\': 1726492500, \'last_updated\': \'2024-09-16 06:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 0, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/122.png\', \'code\': 1009}, \'wind_mph\': 6.3, \'wind_kph\': 10.1, \'wind_degree\': 165, \'wind_dir\': \'SSE\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.2, \'heatindex_c\': 16.8, \'heatindex_f\': 62.2, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 7.3, \'gust_kph\': 11.8}}"}, {\'url\': \'https://www.weathertab.com/en/c/e/09/united-states/california/los-angeles/\', \'content\': \'Explore comprehensive September 2024 weather forecasts for Los Angeles, including daily high and low temperatures, precipitation risks, and monthly temperature trends. Featuring detailed day-by-day forecasts, dynamic graphs of daily rain probabilities, and temperature trends to help you plan ahead. ... 16 84°F 55°F 29°C 13°C 06% 17 87°F 56 ...\'}]', name='tavily_search_results_json', tool_call_id='call_d0gj'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492505, \'localtime\': \'2024-09-16 06:15\'}, \'current\': {\'last_updated_epoch\': 1726492500, \'last_updated\': \'2024-09-16 06:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 0, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/122.png\', \'code\': 1009}, \'wind_mph\': 6.3, \'wind_kph\': 10.1, \'wind_degree\': 165, \'wind_dir\': \'SSE\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.2, \'heatindex_c\': 16.8, \'heatindex_f\': 62.2, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 7.3, \'gust_kph\': 11.8}}"}, {\'url\': \'https://www.ventusky.com/los-angeles\', \'content\': \'Los Angeles ☀ Weather forecast for 10 days, information from meteorological stations, webcams, sunrise and sunset, wind and precipitation maps for this place ... Timezone: America/Los_Angeles (UTC-7) / Current time: 21:20 2024/09/13 . Current Weather ; Forecast ; Sun and Moon ; 20 °C ... 16 km : Clouds ...\'}]', name='tavily_search_results_json', tool_call_id='call_fd1s')]}}, 'step': 7, 'parents': {}}, created_at='2024-09-16T13:15:29.956490+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-aa1f-610b-8006-64615a23d532'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-aa1f-610b-8006-64615a23d532'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_d0gj', 'function': {'arguments': '{"query": "weather in la"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_fd1s', 'function': {'arguments': '{"query": "current weather in los angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 1555, 'total_tokens': 1622, 'completion_time': 0.212250056, 'prompt_time': 0.102976729, 'queue_time': 0.0011719089999999988, 'total_time': 0.315226785}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-8504293e-aa78-402d-8550-c2100ee4b712-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in la'}, 'id': 'call_d0gj', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in los angeles'}, 'id': 'call_fd1s', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1555, 'output_tokens': 67, 'total_tokens': 1622})]}}, 'step': 6, 'parents': {}}, created_at='2024-09-16T13:15:22.529964+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-a0f8-6870-8005-c9c6febda53f'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-a0f8-6870-8005-c9c6febda53f'}}, metadata={'source': 'loop', 'writes': None, 'step': 5, 'parents': {}}, created_at='2024-09-16T13:15:21.570500+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-a0f4-6b21-8004-b5c9a6d0f921'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-a0f4-6b21-8004-b5c9a6d0f921'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='What about in la?')]}}, 'step': 4, 'parents': {}}, created_at='2024-09-16T13:15:21.568919+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d9-0bd7-6d7b-8003-3315d8a00179'}}, tasks=(PregelTask(id='071038dc-016a-e6ee-c3b0-c945af37e034', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d9-0bd7-6d7b-8003-3315d8a00179'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in San Francisco is partly cloudy with a temperature of 13.9°C (57.0°F). The wind is blowing from the west at 10.7 mph (17.3 kph). The humidity is at 89%, and the pressure is 1009.0 hPa (29.78 in). For the next two weeks, the forecast shows mostly sunny conditions with temperatures ranging from 58°F to 76°F.', response_metadata={'token_usage': {'completion_tokens': 92, 'prompt_tokens': 1449, 'total_tokens': 1541, 'completion_time': 0.297921031, 'prompt_time': 0.148236813, 'queue_time': 0.01991232500000001, 'total_time': 0.446157844}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-b7dd39b8-0873-498a-9a1d-a51efbf347e8-0', usage_metadata={'input_tokens': 1449, 'output_tokens': 92, 'total_tokens': 1541})]}}, 'step': 3, 'parents': {}}, created_at='2024-09-16T13:14:12.246195+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d9-0192-66e6-8002-e7f347f13982'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d9-0192-66e6-8002-e7f347f13982'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492280, \'localtime\': \'2024-09-16 06:11\'}, \'current\': {\'last_updated_epoch\': 1726491600, \'last_updated\': \'2024-09-16 06:00\', \'temp_c\': 13.9, \'temp_f\': 57.0, \'is_day\': 0, \'condition\': {\'text\': \'Partly cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 10.7, \'wind_kph\': 17.3, \'wind_degree\': 273, \'wind_dir\': \'W\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.78, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 89, \'cloud\': 75, \'feelslike_c\': 12.5, \'feelslike_f\': 54.5, \'windchill_c\': 11.7, \'windchill_f\': 53.1, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.5, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 15.1, \'gust_kph\': 24.2}}"}, {\'url\': \'https://www.meteoprog.com/weather/Sanfrancisco/month/september/\', \'content\': \'San Francisco (United States) weather in September 2024 ☀️ Accurate weather forecast for San Francisco in September ⛅ Detailed forecast By month Current temperature "near me" Weather news ⊳ Widget of weather ⊳ Water temperature | METEOPROG\'}]', name='tavily_search_results_json', tool_call_id='call_nes8'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492280, \'localtime\': \'2024-09-16 06:11\'}, \'current\': {\'last_updated_epoch\': 1726491600, \'last_updated\': \'2024-09-16 06:00\', \'temp_c\': 13.9, \'temp_f\': 57.0, \'is_day\': 0, \'condition\': {\'text\': \'Partly cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 10.7, \'wind_kph\': 17.3, \'wind_degree\': 273, \'wind_dir\': \'W\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.78, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 89, \'cloud\': 75, \'feelslike_c\': 12.5, \'feelslike_f\': 54.5, \'windchill_c\': 11.7, \'windchill_f\': 53.1, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.5, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 15.1, \'gust_kph\': 24.2}}"}, {\'url\': \'https://www.timeanddate.com/weather/@z-us-94134/ext\', \'content\': \'Forecasted weather conditions the coming 2 weeks for San Francisco. Sign in. News. News Home; Astronomy News; Time Zone News ... 16 pm: Mon Sep 16: 68 / 59 °F ... 6:54 am: 7:11 pm: Thu Sep 19: 70 / 58 °F: Sunny. 76 °F: 8 mph: ↑: 58%: 3%-3 (Moderate) 6:55 am: 7:10 pm * Updated Thursday, September 5, 2024 2:23:50 am San Francisco time ...\'}]', name='tavily_search_results_json', tool_call_id='call_vvah')]}}, 'step': 2, 'parents': {}}, created_at='2024-09-16T13:14:11.169160+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-ad8a-6a60-8001-64bbe88a3c11'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-ad8a-6a60-8001-64bbe88a3c11'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_nes8', 'function': {'arguments': '{"query": "weather in sf"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_vvah', 'function': {'arguments': '{"query": "current weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 293, 'total_tokens': 360, 'completion_time': 0.210940495, 'prompt_time': 0.023038788, 'queue_time': 0.0008450519999999989, 'total_time': 0.233979283}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-169ae4a5-87d4-444a-9a22-699486b9bd18-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in sf'}, 'id': 'call_nes8', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in san francisco'}, 'id': 'call_vvah', 'type': 'tool_call'}], usage_metadata={'input_tokens': 293, 'output_tokens': 67, 'total_tokens': 360})]}}, 'step': 1, 'parents': {}}, created_at='2024-09-16T13:14:02.357973+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0eb-60e3-8000-80579993e005'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0eb-60e3-8000-80579993e005'}}, metadata={'source': 'loop', 'writes': None, 'step': 0, 'parents': {}}, created_at='2024-09-16T13:14:01.034331+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0e7-62a2-bfff-72afab277d42'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0e7-62a2-bfff-72afab277d42'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='What is the weather in sf?')]}}, 'step': -1, 'parents': {}}, created_at='2024-09-16T13:14:01.032759+00:00', parent_config=None, tasks=(PregelTask(id='58f2b54f-b867-f6d8-7396-52dd46d3524d', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))

# %% [markdown]
# Store just the `config` into an list. Note the sequence of counts on the right. `get_state_history` returns the most recent snapshots first.

# %%
states = []
for state in graph.get_state_history(thread):
    states.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fe-67df-805d-48603ca684b0'}} 4
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fc-6ec8-805c-5cbac283a3c3'}} 3
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fb-673f-805b-2378bc354b39'}} 2
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f9-6aaf-805a-df3ce8b50fa0'}} 1
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f6-6fd2-8059-be1a451bbfc9'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f4-6ffd-8058-0259f0957496'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-d461-68b6-8057-041c27a72914'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-b93f-6828-8056-1223f2a62fcc'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-262c-6f46-8055-4eafa2e8ab56'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-0cb2-6338-8054-83e70fb5254d'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-0ca4-6110-8053-947ee40770b9'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f6-c637-65f9-8052-ca3b40d3775d'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f6-c62b-6411-8051-ae16b96d4fba'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f5-9ce1-6307-8050-3d6e63700a0e'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f5-9ccf-6c48-804f-d28ae47f3214'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f2-7410-6327-804e-9246a23300ae'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f2-7407-6913-804d-087f3cfa7b3e'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f1-69fb-68f8-804c-0b4fc8c3d6e9'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f1-69f2-679c-804b-eb3a8c581f21'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f0-e4f0-60ce-804a-3f8d63059d6b'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f0-e4e8-6601-8049-63a7cff3649c'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ee-e34d-6257-8048-38b9631418c2'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ee-e342-607a-8047-cffab1302810'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ec-d80c-66a3-8046-d60599ff1606'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ec-d803-6272-8045-82137705629b'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743e3-39a2-6c64-8044-5d8970f2a609'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743e3-399a-6c19-8043-4995676c0e66'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743df-1e18-661c-8042-2999c7394b3a'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743df-1e0e-609a-8041-d0193db7201c'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7439b-d318-6db4-8040-73f7dc1a38be'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7439b-d310-6ef3-803f-18459f0c6517'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-67f9-6d1c-803e-bf1b008ccb5e'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-586c-635e-803d-f9280823d88f'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-27ad-6540-803c-e78d6bcf02c0'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-1875-6857-803b-a043ed84440b'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-186d-64b5-803a-127191c26462'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-a724-6f14-8039-e03f2839d4c5'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-425e-6afd-8038-440d3fed8bb6'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-1dba-6587-8037-39731dc2c978'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-09e4-6ea4-8036-51ae0ffd82c0'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-09dd-671b-8035-ca181c79a8c5'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-0fb9-6921-8034-c80720c3aa45'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-fcf5-649e-8033-d41923fc4c24'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-d525-6d0f-8032-e5e0af471743'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-c805-626b-8031-63e5cc3b0d15'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-c7fd-68f4-8030-c6723937c17b'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-6ad4-692e-802f-09e2252636cf'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-5e8b-6928-802e-5dde94a5d81c'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-5e84-6610-802d-40c2efc9b32c'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74355-bc12-686c-802c-74eec471a253'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d342-602e-802b-04cfb497ba16'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d33a-6fef-802a-b7c783acab9a'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d30b-6b0d-8029-8ed10a11e0df'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-8115-67be-8028-1cdc347ddaf6'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-5d6d-6c06-8027-3c338ab1ac71'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-527d-65d3-8026-1887f62561c9'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-5277-642e-8025-93ee2100ce30'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-521c-612b-8024-ee29e0bd7963'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-42c5-6fd4-8023-4234edfc0a16'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-14ce-6fde-8022-4b0c521311cf'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-05ae-6a44-8021-e74f5e73f3d2'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-05a8-691f-8020-e8a87534c5ae'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434c-8ece-6689-801f-578b6a12ce3e'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-da46-6653-801e-93f06b134830'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-da32-6ad3-801d-052284659d54'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-d9d5-6ea4-801c-9e03314dae5d'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-642b-635a-801b-701d78710fe1'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-2f4d-6ce9-801a-2bb464ff71c5'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-10c8-6ace-8019-3ac6d135137c'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-10bb-6344-8018-4bf3e9a023c0'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-1061-6864-8017-76233f829b7a'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-06af-639f-8016-f0b815e475bb'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-dc27-6c12-8015-7caf3cc75b3a'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-ca75-6f82-8014-cc3bc39ffff0'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-ca70-60f0-8013-6697d72a30a4'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-a660-6b95-8012-1e04da2b5a71'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-a65c-69b9-8011-72f5fcac3395'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-a644-6d1a-8010-cab7bf83acfd'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-9f02-6619-800f-523e1405465f'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-7787-62f7-800e-2e54c245edde'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-6e83-63f6-800d-acb23667fbcf'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-6e7e-69a9-800c-01db0579e10b'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dc-3b78-6089-800b-a299348694aa'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dc-3340-6315-800a-2db44ebfefd2'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dc-333a-655c-8009-db422a2cdb75'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-fc6d-615a-8008-92bffeb449d5'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-f0f2-63dc-8007-b20522ad79bf'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-aa1f-610b-8006-64615a23d532'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-a0f8-6870-8005-c9c6febda53f'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-a0f4-6b21-8004-b5c9a6d0f921'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d9-0bd7-6d7b-8003-3315d8a00179'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d9-0192-66e6-8002-e7f347f13982'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-ad8a-6a60-8001-64bbe88a3c11'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0eb-60e3-8000-80579993e005'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0e7-62a2-bfff-72afab277d42'}} 0

# %% [markdown]
# Grab an early state.

# %%
states[-3]
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1ef742d8-ad8a-6a60-8001-64bbe88a3c11'}}

# %% [markdown]
# This is the state after Node1 completed for the first time. Note `next` is `Node2`and `count` is 1.

# %%
graph.get_state(states[-3])
# Out:
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-ad8a-6a60-8001-64bbe88a3c11'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_nes8', 'function': {'arguments': '{"query": "weather in sf"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_vvah', 'function': {'arguments': '{"query": "current weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 293, 'total_tokens': 360, 'completion_time': 0.210940495, 'prompt_time': 0.023038788, 'queue_time': 0.0008450519999999989, 'total_time': 0.233979283}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-169ae4a5-87d4-444a-9a22-699486b9bd18-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in sf'}, 'id': 'call_nes8', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in san francisco'}, 'id': 'call_vvah', 'type': 'tool_call'}], usage_metadata={'input_tokens': 293, 'output_tokens': 67, 'total_tokens': 360})]}}, 'step': 1, 'parents': {}}, created_at='2024-09-16T13:14:02.357973+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0eb-60e3-8000-80579993e005'}}, tasks=())

# %% [markdown]
# ### Go Back in Time
# Use that state in `invoke` to go back in time. Notice it uses states[-3] as *current_state* and continues to node2,

# %%
graph.invoke(None, states[-3])
# Out:
# {'count': 0}

# %% [markdown]
# Notice the new states are now in state history. Notice the counts on the far right.

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fe-67df-805d-48603ca684b0'}} 4
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fc-6ec8-805c-5cbac283a3c3'}} 3
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fb-673f-805b-2378bc354b39'}} 2
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f9-6aaf-805a-df3ce8b50fa0'}} 1
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f6-6fd2-8059-be1a451bbfc9'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f4-6ffd-8058-0259f0957496'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-d461-68b6-8057-041c27a72914'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-b93f-6828-8056-1223f2a62fcc'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-262c-6f46-8055-4eafa2e8ab56'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-0cb2-6338-8054-83e70fb5254d'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-0ca4-6110-8053-947ee40770b9'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f6-c637-65f9-8052-ca3b40d3775d'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f6-c62b-6411-8051-ae16b96d4fba'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f5-9ce1-6307-8050-3d6e63700a0e'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f5-9ccf-6c48-804f-d28ae47f3214'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f2-7410-6327-804e-9246a23300ae'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f2-7407-6913-804d-087f3cfa7b3e'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f1-69fb-68f8-804c-0b4fc8c3d6e9'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f1-69f2-679c-804b-eb3a8c581f21'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f0-e4f0-60ce-804a-3f8d63059d6b'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f0-e4e8-6601-8049-63a7cff3649c'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ee-e34d-6257-8048-38b9631418c2'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ee-e342-607a-8047-cffab1302810'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ec-d80c-66a3-8046-d60599ff1606'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ec-d803-6272-8045-82137705629b'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743e3-39a2-6c64-8044-5d8970f2a609'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743e3-399a-6c19-8043-4995676c0e66'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743df-1e18-661c-8042-2999c7394b3a'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743df-1e0e-609a-8041-d0193db7201c'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7439b-d318-6db4-8040-73f7dc1a38be'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7439b-d310-6ef3-803f-18459f0c6517'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-67f9-6d1c-803e-bf1b008ccb5e'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-586c-635e-803d-f9280823d88f'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-27ad-6540-803c-e78d6bcf02c0'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-1875-6857-803b-a043ed84440b'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-186d-64b5-803a-127191c26462'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-a724-6f14-8039-e03f2839d4c5'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-425e-6afd-8038-440d3fed8bb6'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-1dba-6587-8037-39731dc2c978'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-09e4-6ea4-8036-51ae0ffd82c0'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-09dd-671b-8035-ca181c79a8c5'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-0fb9-6921-8034-c80720c3aa45'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-fcf5-649e-8033-d41923fc4c24'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-d525-6d0f-8032-e5e0af471743'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-c805-626b-8031-63e5cc3b0d15'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-c7fd-68f4-8030-c6723937c17b'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-6ad4-692e-802f-09e2252636cf'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-5e8b-6928-802e-5dde94a5d81c'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-5e84-6610-802d-40c2efc9b32c'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74355-bc12-686c-802c-74eec471a253'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d342-602e-802b-04cfb497ba16'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d33a-6fef-802a-b7c783acab9a'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d30b-6b0d-8029-8ed10a11e0df'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-8115-67be-8028-1cdc347ddaf6'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-5d6d-6c06-8027-3c338ab1ac71'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-527d-65d3-8026-1887f62561c9'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-5277-642e-8025-93ee2100ce30'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-521c-612b-8024-ee29e0bd7963'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-42c5-6fd4-8023-4234edfc0a16'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-14ce-6fde-8022-4b0c521311cf'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-05ae-6a44-8021-e74f5e73f3d2'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-05a8-691f-8020-e8a87534c5ae'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434c-8ece-6689-801f-578b6a12ce3e'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-da46-6653-801e-93f06b134830'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-da32-6ad3-801d-052284659d54'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-d9d5-6ea4-801c-9e03314dae5d'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-642b-635a-801b-701d78710fe1'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-2f4d-6ce9-801a-2bb464ff71c5'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-10c8-6ace-8019-3ac6d135137c'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-10bb-6344-8018-4bf3e9a023c0'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-1061-6864-8017-76233f829b7a'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434b-06af-639f-8016-f0b815e475bb'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-dc27-6c12-8015-7caf3cc75b3a'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-ca75-6f82-8014-cc3bc39ffff0'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-ca70-60f0-8013-6697d72a30a4'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-a660-6b95-8012-1e04da2b5a71'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-a65c-69b9-8011-72f5fcac3395'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-a644-6d1a-8010-cab7bf83acfd'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-9f02-6619-800f-523e1405465f'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-7787-62f7-800e-2e54c245edde'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-6e83-63f6-800d-acb23667fbcf'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434a-6e7e-69a9-800c-01db0579e10b'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dc-3b78-6089-800b-a299348694aa'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dc-3340-6315-800a-2db44ebfefd2'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dc-333a-655c-8009-db422a2cdb75'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-fc6d-615a-8008-92bffeb449d5'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-f0f2-63dc-8007-b20522ad79bf'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-aa1f-610b-8006-64615a23d532'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-a0f8-6870-8005-c9c6febda53f'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-a0f4-6b21-8004-b5c9a6d0f921'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d9-0bd7-6d7b-8003-3315d8a00179'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d9-0192-66e6-8002-e7f347f13982'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-ad8a-6a60-8001-64bbe88a3c11'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0eb-60e3-8000-80579993e005'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0e7-62a2-bfff-72afab277d42'}} 0

# %% [markdown]
# You can see the details below. Lots of text, but try to find the node that start the new branch. Notice the parent *config* is not the previous entry in the stack, but is the entry from state[-3].

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fe-67df-805d-48603ca684b0'}}, metadata={'source': 'loop', 'writes': {'Node2': {'lnode': 'node_2', 'count': 1}}, 'step': 93, 'parents': {}}, created_at='2024-09-16T15:27:22.516052+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fc-6ec8-805c-5cbac283a3c3'}}, tasks=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fc-6ec8-805c-5cbac283a3c3'}}, metadata={'source': 'loop', 'writes': {'Node1': {'lnode': 'node_1', 'count': 1}}, 'step': 92, 'parents': {}}, created_at='2024-09-16T15:27:22.515414+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fb-673f-805b-2378bc354b39'}}, tasks=(PregelTask(id='5360fafa-4f71-40bf-b3e5-0f018794ca7e', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4fb-673f-805b-2378bc354b39'}}, metadata={'source': 'loop', 'writes': {'Node2': {'lnode': 'node_2', 'count': 1}}, 'step': 91, 'parents': {}}, created_at='2024-09-16T15:27:22.514811+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f9-6aaf-805a-df3ce8b50fa0'}}, tasks=(PregelTask(id='8795efd9-7770-5fa4-4f2b-78892772171b', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f9-6aaf-805a-df3ce8b50fa0'}}, metadata={'source': 'loop', 'writes': {'Node1': {'lnode': 'node_1', 'count': 1}}, 'step': 90, 'parents': {}}, created_at='2024-09-16T15:27:22.514081+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f6-6fd2-8059-be1a451bbfc9'}}, tasks=(PregelTask(id='8f51cbc8-288a-c8b4-01ac-12e3e10c7520', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f6-6fd2-8059-be1a451bbfc9'}}, metadata={'source': 'loop', 'writes': None, 'step': 89, 'parents': {}}, created_at='2024-09-16T15:27:22.512983+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f4-6ffd-8058-0259f0957496'}}, tasks=(PregelTask(id='1a1bfa64-59d2-4fa0-aaac-b5b1ad6cc559', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74402-b4f4-6ffd-8058-0259f0957496'}}, metadata={'source': 'input', 'writes': {'__start__': {'count': 0, 'scratch': 'hi'}}, 'step': 88, 'parents': {}}, created_at='2024-09-16T15:27:22.512165+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-d461-68b6-8057-041c27a72914'}}, tasks=(PregelTask(id='1e680ccd-237d-76fa-ee2a-c07ac1f051e7', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-d461-68b6-8057-041c27a72914'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in San Francisco is overcast with a temperature of 14.4°C (57.9°F). The wind is coming from the west at 5.8 mph (9.4 kph). The humidity is at 87%, and the pressure is 1010.0 hPa (29.82 in). For the month of September, the forecast shows mostly sunny conditions with temperatures ranging from 53.8°F (12.1°C) to 70°F (21.1°C).', response_metadata={'token_usage': {'completion_tokens': 105, 'prompt_tokens': 8571, 'total_tokens': 8676, 'completion_time': 0.14, 'prompt_time': 1.82839769, 'queue_time': 0.0037005679999999597, 'total_time': 1.96839769}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f66ccb39ec', 'finish_reason': 'stop', 'logprobs': None}, id='run-207d1ac9-4f62-425d-8606-89225515572d-0', usage_metadata={'input_tokens': 8571, 'output_tokens': 105, 'total_tokens': 8676})]}}, 'step': 87, 'parents': {}}, created_at='2024-09-16T15:23:24.215244+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-b93f-6828-8056-1223f2a62fcc'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-b93f-6828-8056-1223f2a62fcc'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726500181, \'localtime\': \'2024-09-16 08:23\'}, \'current\': {\'last_updated_epoch\': 1726499700, \'last_updated\': \'2024-09-16 08:15\', \'temp_c\': 14.4, \'temp_f\': 57.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 5.8, \'wind_kph\': 9.4, \'wind_degree\': 276, \'wind_dir\': \'W\', \'pressure_mb\': 1010.0, \'pressure_in\': 29.82, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 87, \'cloud\': 100, \'feelslike_c\': 14.0, \'feelslike_f\': 57.1, \'windchill_c\': 12.7, \'windchill_f\': 54.8, \'heatindex_c\': 13.0, \'heatindex_f\': 55.3, \'dewpoint_c\': 12.1, \'dewpoint_f\': 53.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 3.0, \'gust_mph\': 8.0, \'gust_kph\': 12.9}}"}, {\'url\': \'https://www.weathertab.com/en/c/e/09/united-states/california/san-francisco/\', \'content\': \'Explore comprehensive September 2024 weather forecasts for San Francisco, including daily high and low temperatures, precipitation risks, and monthly temperature trends. Featuring detailed day-by-day forecasts, dynamic graphs of daily rain probabilities, and temperature trends to help you plan ahead.\'}]', name='tavily_search_results_json', id='2609362d-cc84-43a0-b775-056954424201', tool_call_id='call_nkqr')]}}, 'step': 86, 'parents': {}}, created_at='2024-09-16T15:23:21.370155+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-262c-6f46-8055-4eafa2e8ab56'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-262c-6f46-8055-4eafa2e8ab56'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_nkqr', 'function': {'arguments': '{"query": "weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 8049, 'total_tokens': 8071, 'completion_time': 0.029333333, 'prompt_time': 1.67612209, 'queue_time': 0.030606365999999996, 'total_time': 1.705455423}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_9cb648b966', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-25919bf4-cf26-4467-bee5-2f32df978e44-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in san francisco'}, 'id': 'call_nkqr', 'type': 'tool_call'}], usage_metadata={'input_tokens': 8049, 'output_tokens': 22, 'total_tokens': 8071})]}}, 'step': 85, 'parents': {}}, created_at='2024-09-16T15:23:05.948525+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-0cb2-6338-8054-83e70fb5254d'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-0cb2-6338-8054-83e70fb5254d'}}, metadata={'source': 'loop', 'writes': None, 'step': 84, 'parents': {}}, created_at='2024-09-16T15:23:03.276804+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-0ca4-6110-8053-947ee40770b9'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-0ca4-6110-8053-947ee40770b9'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 83, 'parents': {}}, created_at='2024-09-16T15:23:03.271012+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f6-c637-65f9-8052-ca3b40d3775d'}}, tasks=(PregelTask(id='7f72f8b4-d616-73d9-02b1-a5a344617abc', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f6-c637-65f9-8052-ca3b40d3775d'}}, metadata={'source': 'loop', 'writes': None, 'step': 82, 'parents': {}}, created_at='2024-09-16T15:22:02.199380+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f6-c62b-6411-8051-ae16b96d4fba'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f6-c62b-6411-8051-ae16b96d4fba'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 81, 'parents': {}}, created_at='2024-09-16T15:22:02.194409+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f5-9ce1-6307-8050-3d6e63700a0e'}}, tasks=(PregelTask(id='147a079e-b542-7e2b-5efc-be4499a00bda', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f5-9ce1-6307-8050-3d6e63700a0e'}}, metadata={'source': 'loop', 'writes': None, 'step': 80, 'parents': {}}, created_at='2024-09-16T15:21:31.021362+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f5-9ccf-6c48-804f-d28ae47f3214'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f5-9ccf-6c48-804f-d28ae47f3214'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 79, 'parents': {}}, created_at='2024-09-16T15:21:31.014228+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f2-7410-6327-804e-9246a23300ae'}}, tasks=(PregelTask(id='85679f1c-4f81-340f-3157-f36e4e374a2c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f2-7410-6327-804e-9246a23300ae'}}, metadata={'source': 'loop', 'writes': None, 'step': 78, 'parents': {}}, created_at='2024-09-16T15:20:06.210831+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f2-7407-6913-804d-087f3cfa7b3e'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f2-7407-6913-804d-087f3cfa7b3e'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 77, 'parents': {}}, created_at='2024-09-16T15:20:06.207291+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f1-69fb-68f8-804c-0b4fc8c3d6e9'}}, tasks=(PregelTask(id='e8bb1c0f-9508-2c4d-0ceb-fc234e175688', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f1-69fb-68f8-804c-0b4fc8c3d6e9'}}, metadata={'source': 'loop', 'writes': None, 'step': 76, 'parents': {}}, created_at='2024-09-16T15:19:38.310248+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f1-69f2-679c-804b-eb3a8c581f21'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f1-69f2-679c-804b-eb3a8c581f21'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 75, 'parents': {}}, created_at='2024-09-16T15:19:38.306531+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f0-e4f0-60ce-804a-3f8d63059d6b'}}, tasks=(PregelTask(id='d5d976d5-63d5-7b82-88c8-060176d0f88a', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f0-e4f0-60ce-804a-3f8d63059d6b'}}, metadata={'source': 'loop', 'writes': None, 'step': 74, 'parents': {}}, created_at='2024-09-16T15:19:24.359482+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f0-e4e8-6601-8049-63a7cff3649c'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f0-e4e8-6601-8049-63a7cff3649c'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 73, 'parents': {}}, created_at='2024-09-16T15:19:24.356335+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ee-e34d-6257-8048-38b9631418c2'}}, tasks=(PregelTask(id='7869446b-f34d-1253-272e-eb0029a63516', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ee-e34d-6257-8048-38b9631418c2'}}, metadata={'source': 'loop', 'writes': None, 'step': 72, 'parents': {}}, created_at='2024-09-16T15:18:30.500798+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ee-e342-607a-8047-cffab1302810'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ee-e342-607a-8047-cffab1302810'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 71, 'parents': {}}, created_at='2024-09-16T15:18:30.496242+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ec-d80c-66a3-8046-d60599ff1606'}}, tasks=(PregelTask(id='dcefa564-2153-9034-e41d-dcba9a8f5d30', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ec-d80c-66a3-8046-d60599ff1606'}}, metadata={'source': 'loop', 'writes': None, 'step': 70, 'parents': {}}, created_at='2024-09-16T15:17:35.633768+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ec-d803-6272-8045-82137705629b'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743ec-d803-6272-8045-82137705629b'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 69, 'parents': {}}, created_at='2024-09-16T15:17:35.629962+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743e3-39a2-6c64-8044-5d8970f2a609'}}, tasks=(PregelTask(id='36cf838b-66bf-0ebc-d378-79bc55668ec0', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743e3-39a2-6c64-8044-5d8970f2a609'}}, metadata={'source': 'loop', 'writes': None, 'step': 68, 'parents': {}}, created_at='2024-09-16T15:13:17.431086+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743e3-399a-6c19-8043-4995676c0e66'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743e3-399a-6c19-8043-4995676c0e66'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 67, 'parents': {}}, created_at='2024-09-16T15:13:17.427797+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743df-1e18-661c-8042-2999c7394b3a'}}, tasks=(PregelTask(id='052c0f10-f04a-96a2-b9ad-6fafdb7192f5', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743df-1e18-661c-8042-2999c7394b3a'}}, metadata={'source': 'loop', 'writes': None, 'step': 66, 'parents': {}}, created_at='2024-09-16T15:11:27.169054+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743df-1e0e-609a-8041-d0193db7201c'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef743df-1e0e-609a-8041-d0193db7201c'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 65, 'parents': {}}, created_at='2024-09-16T15:11:27.164813+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7439b-d318-6db4-8040-73f7dc1a38be'}}, tasks=(PregelTask(id='2facf453-9f64-7b5c-f64b-d22093b42016', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7439b-d318-6db4-8040-73f7dc1a38be'}}, metadata={'source': 'loop', 'writes': None, 'step': 64, 'parents': {}}, created_at='2024-09-16T14:41:20.787384+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7439b-d310-6ef3-803f-18459f0c6517'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7439b-d310-6ef3-803f-18459f0c6517'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 63, 'parents': {}}, created_at='2024-09-16T14:41:20.784133+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-67f9-6d1c-803e-bf1b008ccb5e'}}, tasks=(PregelTask(id='8e8e929c-9b21-05ee-45e5-26b7017fc778', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-67f9-6d1c-803e-bf1b008ccb5e'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in San Francisco is overcast with a temperature of 14.4°C (57', response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 8173, 'total_tokens': 8193, 'completion_time': 0.06058844, 'prompt_time': 0.541126708, 'queue_time': 0.002027549999999989, 'total_time': 0.601715148}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-114fb5bf-1897-4ec1-9c59-0938d53b69a3-0', usage_metadata={'input_tokens': 8173, 'output_tokens': 20, 'total_tokens': 8193})]}}, 'step': 62, 'parents': {}}, created_at='2024-09-16T14:39:22.180670+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-586c-635e-803d-f9280823d88f'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-586c-635e-803d-f9280823d88f'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726497538, \'localtime\': \'2024-09-16 07:38\'}, \'current\': {\'last_updated_epoch\': 1726497000, \'last_updated\': \'2024-09-16 07:30\', \'temp_c\': 14.4, \'temp_f\': 57.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 274, \'wind_dir\': \'W\', \'pressure_mb\': 1010.0, \'pressure_in\': 29.81, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 87, \'cloud\': 100, \'feelslike_c\': 13.4, \'feelslike_f\': 56.2, \'windchill_c\': 12.4, \'windchill_f\': 54.3, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.7, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 3.0, \'gust_mph\': 12.1, \'gust_kph\': 19.5}}"}, {\'url\': \'https://forecast.weather.gov/MapClick.php?lat=37.6188&lon=-122.3758\', \'content\': \'Current conditions at San Francisco, San Francisco International Airport (KSFO) Lat: 37.61961°NLon: ... 2024-6pm PDT Sep 16, 2024 . Forecast Discussion . Additional Resources. Radar & Satellite Image. ... National Weather Service; San Francisco Bay Area, CA; 21 Grace Hopper Ave, Stop 5; Monterey, CA 93943-5505; Comments? Questions?\'}]', name='tavily_search_results_json', id='151dc5a4-e0b0-4e3d-a8d2-914a932490b1', tool_call_id='call_xpde')]}}, 'step': 61, 'parents': {}}, created_at='2024-09-16T14:39:20.549801+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-27ad-6540-803c-e78d6bcf02c0'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-27ad-6540-803c-e78d6bcf02c0'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_xpde', 'function': {'arguments': '{"query":"weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 7583, 'total_tokens': 7616, 'completion_time': 0.102372705, 'prompt_time': 0.634856878, 'queue_time': 0.0021635369999999376, 'total_time': 0.737229583}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-e9b6d17e-688b-4fd9-92db-bf1d974b6d06-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in san francisco'}, 'id': 'call_xpde', 'type': 'tool_call'}], usage_metadata={'input_tokens': 7583, 'output_tokens': 33, 'total_tokens': 7616})]}}, 'step': 60, 'parents': {}}, created_at='2024-09-16T14:39:15.438508+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-1875-6857-803b-a043ed84440b'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-1875-6857-803b-a043ed84440b'}}, metadata={'source': 'loop', 'writes': None, 'step': 59, 'parents': {}}, created_at='2024-09-16T14:39:13.842785+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-186d-64b5-803a-127191c26462'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-186d-64b5-803a-127191c26462'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 58, 'parents': {}}, created_at='2024-09-16T14:39:13.839410+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-a724-6f14-8039-e03f2839d4c5'}}, tasks=(PregelTask(id='a0f8fb30-7151-b666-831a-92cdabfb6d55', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-a724-6f14-8039-e03f2839d4c5'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in San Francisco is overcast with a temperature of 14.4°C (57.9°F). The wind is coming from the west at 8.7 mph (14.0 kph). The humidity is at 87%, and the pressure is 1010.0 hPa (29.81 in). For the month of September, the forecast shows mostly sunny conditions with temperatures ranging from 51°F (10.6°C) to 70°F (21.1°C).', response_metadata={'token_usage': {'completion_tokens': 103, 'prompt_tokens': 7465, 'total_tokens': 7568, 'completion_time': 0.326495861, 'prompt_time': 0.797492551, 'queue_time': 0.0020620899999999054, 'total_time': 1.123988412}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-ba9e27c2-a12e-4608-a0a2-8b747077bf86-0', usage_metadata={'input_tokens': 7465, 'output_tokens': 103, 'total_tokens': 7568})]}}, 'step': 57, 'parents': {}}, created_at='2024-09-16T14:26:30.341579+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-425e-6afd-8038-440d3fed8bb6'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-425e-6afd-8038-440d3fed8bb6'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496725, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 14.4, \'temp_f\': 57.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 274, \'wind_dir\': \'W\', \'pressure_mb\': 1010.0, \'pressure_in\': 29.81, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 87, \'cloud\': 100, \'feelslike_c\': 13.4, \'feelslike_f\': 56.2, \'windchill_c\': 12.4, \'windchill_f\': 54.3, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.7, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 3.0, \'gust_mph\': 12.1, \'gust_kph\': 19.5}}"}, {\'url\': \'https://weather.com/weather/monthly/l/69bedc6a5b6e977993fb3e5344e3c06d8bc36a1fb6754c3ddfb5310a3c6d6c87\', \'content\': \'Weather.com brings you the most accurate monthly weather forecast for San Francisco, ... 16 64 ° 51 ° 17. 61 ° 52 ° 18 ... September: 70 ° 56 ° 0: October: 70 ° 54 ...\'}]', name='tavily_search_results_json', id='73629667-b63a-4de3-b797-5d4e9cd92ae8', tool_call_id='call_v8s1')]}}, 'step': 56, 'parents': {}}, created_at='2024-09-16T14:26:19.774578+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-1dba-6587-8037-39731dc2c978'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-1dba-6587-8037-39731dc2c978'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_v8s1', 'function': {'arguments': '{"query":"weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 6884, 'total_tokens': 6917, 'completion_time': 0.10212899, 'prompt_time': 0.505107015, 'queue_time': 0.0018245439999999835, 'total_time': 0.607236005}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-20ccfba2-aa9e-4517-9ec3-6d7857e3667d-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in san francisco'}, 'id': 'call_v8s1', 'type': 'tool_call'}], usage_metadata={'input_tokens': 6884, 'output_tokens': 33, 'total_tokens': 6917})]}}, 'step': 55, 'parents': {}}, created_at='2024-09-16T14:26:15.932432+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-09e4-6ea4-8036-51ae0ffd82c0'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-09e4-6ea4-8036-51ae0ffd82c0'}}, metadata={'source': 'loop', 'writes': None, 'step': 54, 'parents': {}}, created_at='2024-09-16T14:26:13.852725+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-09dd-671b-8035-ca181c79a8c5'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-09dd-671b-8035-ca181c79a8c5'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 53, 'parents': {}}, created_at='2024-09-16T14:26:13.849659+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-0fb9-6921-8034-c80720c3aa45'}}, tasks=(PregelTask(id='60a72a44-eb63-b0d7-499e-e72e2577a53f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-0fb9-6921-8034-c80720c3aa45'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in San Francisco is overcast with a temperature of 14.4°C (57.9°F). The wind is coming from the west at 8.7 mph (14.0 kph). The humidity is at 87%, and the pressure is 1010.0 hPa (29.81 in). For the next two weeks, the forecast shows mostly sunny conditions with temperatures ranging from 58°F (14.4°C) to 70°F (21.1°C).', response_metadata={'token_usage': {'completion_tokens': 103, 'prompt_tokens': 6766, 'total_tokens': 6869, 'completion_time': 0.325426963, 'prompt_time': 0.535805377, 'queue_time': 0.0019882770000000383, 'total_time': 0.86123234}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-9e33a34e-e9bf-447c-ab00-6a38fbf1c1bc-0', usage_metadata={'input_tokens': 6766, 'output_tokens': 103, 'total_tokens': 6869})]}}, 'step': 52, 'parents': {}}, created_at='2024-09-16T14:25:47.620572+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-fcf5-649e-8033-d41923fc4c24'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-fcf5-649e-8033-d41923fc4c24'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726496725, \'localtime\': \'2024-09-16 07:25\'}, \'current\': {\'last_updated_epoch\': 1726496100, \'last_updated\': \'2024-09-16 07:15\', \'temp_c\': 14.4, \'temp_f\': 57.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 274, \'wind_dir\': \'W\', \'pressure_mb\': 1010.0, \'pressure_in\': 29.81, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 87, \'cloud\': 100, \'feelslike_c\': 13.4, \'feelslike_f\': 56.2, \'windchill_c\': 12.4, \'windchill_f\': 54.3, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.7, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 3.0, \'gust_mph\': 12.1, \'gust_kph\': 19.5}}"}, {\'url\': \'https://www.timeanddate.com/weather/@z-us-94134/ext\', \'content\': \'Forecasted weather conditions the coming 2 weeks for San Francisco. Sign in. News. News Home; Astronomy News; Time Zone News ... 16 pm: Mon Sep 16: 68 / 59 °F ... 6:54 am: 7:11 pm: Thu Sep 19: 70 / 58 °F: Sunny. 76 °F: 8 mph: ↑: 58%: 3%-3 (Moderate) 6:55 am: 7:10 pm * Updated Thursday, September 5, 2024 2:23:50 am San Francisco time ...\'}]', name='tavily_search_results_json', id='66273b1c-948a-4d07-9192-698dc3fb8b38', tool_call_id='call_6dhj')]}}, 'step': 51, 'parents': {}}, created_at='2024-09-16T14:25:45.652683+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-d525-6d0f-8032-e5e0af471743'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-d525-6d0f-8032-e5e0af471743'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6dhj', 'function': {'arguments': '{"query":"weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 6148, 'total_tokens': 6181, 'completion_time': 0.103653227, 'prompt_time': 0.41728126, 'queue_time': 0.0018017270000000307, 'total_time': 0.520934487}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-e6f9810b-49aa-4e4d-818a-e25e645bdaa9-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in san francisco'}, 'id': 'call_6dhj', 'type': 'tool_call'}], usage_metadata={'input_tokens': 6148, 'output_tokens': 33, 'total_tokens': 6181})]}}, 'step': 50, 'parents': {}}, created_at='2024-09-16T14:25:41.478299+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-c805-626b-8031-63e5cc3b0d15'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-c805-626b-8031-63e5cc3b0d15'}}, metadata={'source': 'loop', 'writes': None, 'step': 49, 'parents': {}}, created_at='2024-09-16T14:25:40.101782+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-c7fd-68f4-8030-c6723937c17b'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74378-c7fd-68f4-8030-c6723937c17b'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 48, 'parents': {}}, created_at='2024-09-16T14:25:40.098639+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-6ad4-692e-802f-09e2252636cf'}}, tasks=(PregelTask(id='69700574-9b6a-4aaa-a909-07f3f0ea2a9c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-6ad4-692e-802f-09e2252636cf'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_bkfm', 'function': {'arguments': '{"query":"weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 6102, 'total_tokens': 6135, 'completion_time': 0.102237688, 'prompt_time': 0.37884695, 'queue_time': 0.0018910799999999894, 'total_time': 0.481084638}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-20134833-0ed1-4e0a-803d-1509ec6ec338-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in san francisco'}, 'id': 'call_bkfm', 'type': 'tool_call'}], usage_metadata={'input_tokens': 6102, 'output_tokens': 33, 'total_tokens': 6135})]}}, 'step': 47, 'parents': {}}, created_at='2024-09-16T14:20:08.207583+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-5e8b-6928-802e-5dde94a5d81c'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-5e8b-6928-802e-5dde94a5d81c'}}, metadata={'source': 'loop', 'writes': None, 'step': 46, 'parents': {}}, created_at='2024-09-16T14:20:06.919388+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-5e84-6610-802d-40c2efc9b32c'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef7436c-5e84-6610-802d-40c2efc9b32c'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in SF?')]}}, 'step': 45, 'parents': {}}, created_at='2024-09-16T14:20:06.916436+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74355-bc12-686c-802c-74eec471a253'}}, tasks=(PregelTask(id='e8575abf-9273-b646-b34d-8f4387deb87f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74355-bc12-686c-802c-74eec471a253'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='Los Angeles is warmer than San Francisco.', response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 6078, 'total_tokens': 6087, 'completion_time': 0.025626901, 'prompt_time': 0.38679303, 'queue_time': 0.0016302590000000228, 'total_time': 0.412419931}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-468a7f28-e5dc-4375-a598-0a6012e375ed-0', usage_metadata={'input_tokens': 6078, 'output_tokens': 9, 'total_tokens': 6087})]}}, 'step': 44, 'parents': {}}, created_at='2024-09-16T14:09:59.324812+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d342-602e-802b-04cfb497ba16'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d342-602e-802b-04cfb497ba16'}}, metadata={'source': 'loop', 'writes': None, 'step': 43, 'parents': {}}, created_at='2024-09-16T14:09:34.912496+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d33a-6fef-802a-b7c783acab9a'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d33a-6fef-802a-b7c783acab9a'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Which one is warmer?')]}}, 'step': 42, 'parents': {}}, created_at='2024-09-16T14:09:34.909619+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d30b-6b0d-8029-8ed10a11e0df'}}, tasks=(PregelTask(id='c8db5d88-506c-c73f-3500-8345e682aad9', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-d30b-6b0d-8029-8ed10a11e0df'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in Los Angeles is overcast with a temperature of 18.3°C (64.9°F). The wind is coming from the south at 7.2 mph (11.5 kph). The humidity is at 81%, and the pressure is 1011.0 hPa (29.85 in). For the month of September, the forecast shows mostly sunny conditions with temperatures ranging from 64.4°F (18°C) to 82.2°F (27.9°C).', response_metadata={'token_usage': {'completion_tokens': 105, 'prompt_tokens': 5959, 'total_tokens': 6064, 'completion_time': 0.334021861, 'prompt_time': 0.391028568, 'queue_time': 0.0015205070000000043, 'total_time': 0.725050429}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-2e136a1f-2ef3-4e14-aa76-50d482c04e5a-0', usage_metadata={'input_tokens': 5959, 'output_tokens': 105, 'total_tokens': 6064})]}}, 'step': 41, 'parents': {}}, created_at='2024-09-16T14:09:34.890252+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-8115-67be-8028-1cdc347ddaf6'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-8115-67be-8028-1cdc347ddaf6'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726495746, \'localtime\': \'2024-09-16 07:09\'}, \'current\': {\'last_updated_epoch\': 1726495200, \'last_updated\': \'2024-09-16 07:00\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.weather.gov/lox/\', \'content\': \'Current Hazards. Daily Briefing; Latest Hazard Listing; Current Outlooks; ... Sep 16, 2024 at 2:04:08 am PDT Watches, Warnings & Advisories. Zoom Out. Gale Warning. Small Craft Advisory. Wind Advisory. ... National Weather Service Los Angeles, CA 520 North Elevar Street Oxnard, CA 93030 805-988-6610 Comments? Questions?\'}]', name='tavily_search_results_json', tool_call_id='call_36p3')]}}, 'step': 40, 'parents': {}}, created_at='2024-09-16T14:09:26.295942+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-5d6d-6c06-8027-3c338ab1ac71'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-5d6d-6c06-8027-3c338ab1ac71'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_36p3', 'function': {'arguments': '{"query":"weather in los angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 5387, 'total_tokens': 5420, 'completion_time': 0.104801284, 'prompt_time': 0.328606256, 'queue_time': 0.0018235289999999904, 'total_time': 0.43340754}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2f1e544e-d11a-4774-9051-fc90469bcbb3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in los angeles'}, 'id': 'call_36p3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 5387, 'output_tokens': 33, 'total_tokens': 5420})]}}, 'step': 39, 'parents': {}}, created_at='2024-09-16T14:09:22.557150+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-527d-65d3-8026-1887f62561c9'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-527d-65d3-8026-1887f62561c9'}}, metadata={'source': 'loop', 'writes': None, 'step': 38, 'parents': {}}, created_at='2024-09-16T14:09:21.410183+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-5277-642e-8025-93ee2100ce30'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-5277-642e-8025-93ee2100ce30'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='What about in la?')]}}, 'step': 37, 'parents': {}}, created_at='2024-09-16T14:09:21.407679+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef74354-521c-612b-8024-ee29e0bd7963'}}, tasks=(PregelTask(id='83adb830-556d-6c05-52b1-0c0f9339aadc', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# ...
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dc-3340-6315-800a-2db44ebfefd2'}}, metadata={'source': 'loop', 'writes': None, 'step': 10, 'parents': {}}, created_at='2024-09-16T13:15:36.909062+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dc-333a-655c-8009-db422a2cdb75'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dc-333a-655c-8009-db422a2cdb75'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Which one is warmer?')]}}, 'step': 9, 'parents': {}}, created_at='2024-09-16T13:15:36.906665+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-fc6d-615a-8008-92bffeb449d5'}}, tasks=(PregelTask(id='95a67edd-4f47-2236-7b8c-1610c857cd2e', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-fc6d-615a-8008-92bffeb449d5'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in Los Angeles is overcast with a temperature of 18.3°C (64.9°F). The wind is coming from the southeast at 6.3 mph (10.1 kph). The humidity is at 81%, and the pressure is 1011.0 hPa (29.85 in). For the next 10 days, the forecast shows mostly sunny conditions with temperatures ranging from 20°C to 25°C.', response_metadata={'token_usage': {'completion_tokens': 93, 'prompt_tokens': 2692, 'total_tokens': 2785, 'completion_time': 0.296655938, 'prompt_time': 0.22501293, 'queue_time': 0.0015646679999999913, 'total_time': 0.521668868}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-1aafb96a-3ee5-4183-b771-57f25fc59790-0', usage_metadata={'input_tokens': 2692, 'output_tokens': 93, 'total_tokens': 2785})]}}, 'step': 8, 'parents': {}}, created_at='2024-09-16T13:15:31.160291+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-f0f2-63dc-8007-b20522ad79bf'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-f0f2-63dc-8007-b20522ad79bf'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492505, \'localtime\': \'2024-09-16 06:15\'}, \'current\': {\'last_updated_epoch\': 1726492500, \'last_updated\': \'2024-09-16 06:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 0, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/122.png\', \'code\': 1009}, \'wind_mph\': 6.3, \'wind_kph\': 10.1, \'wind_degree\': 165, \'wind_dir\': \'SSE\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.2, \'heatindex_c\': 16.8, \'heatindex_f\': 62.2, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 7.3, \'gust_kph\': 11.8}}"}, {\'url\': \'https://www.weathertab.com/en/c/e/09/united-states/california/los-angeles/\', \'content\': \'Explore comprehensive September 2024 weather forecasts for Los Angeles, including daily high and low temperatures, precipitation risks, and monthly temperature trends. Featuring detailed day-by-day forecasts, dynamic graphs of daily rain probabilities, and temperature trends to help you plan ahead. ... 16 84°F 55°F 29°C 13°C 06% 17 87°F 56 ...\'}]', name='tavily_search_results_json', tool_call_id='call_d0gj'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492505, \'localtime\': \'2024-09-16 06:15\'}, \'current\': {\'last_updated_epoch\': 1726492500, \'last_updated\': \'2024-09-16 06:15\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 0, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/122.png\', \'code\': 1009}, \'wind_mph\': 6.3, \'wind_kph\': 10.1, \'wind_degree\': 165, \'wind_dir\': \'SSE\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.2, \'heatindex_c\': 16.8, \'heatindex_f\': 62.2, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 7.3, \'gust_kph\': 11.8}}"}, {\'url\': \'https://www.ventusky.com/los-angeles\', \'content\': \'Los Angeles ☀ Weather forecast for 10 days, information from meteorological stations, webcams, sunrise and sunset, wind and precipitation maps for this place ... Timezone: America/Los_Angeles (UTC-7) / Current time: 21:20 2024/09/13 . Current Weather ; Forecast ; Sun and Moon ; 20 °C ... 16 km : Clouds ...\'}]', name='tavily_search_results_json', tool_call_id='call_fd1s')]}}, 'step': 7, 'parents': {}}, created_at='2024-09-16T13:15:29.956490+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-aa1f-610b-8006-64615a23d532'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-aa1f-610b-8006-64615a23d532'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_d0gj', 'function': {'arguments': '{"query": "weather in la"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_fd1s', 'function': {'arguments': '{"query": "current weather in los angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 1555, 'total_tokens': 1622, 'completion_time': 0.212250056, 'prompt_time': 0.102976729, 'queue_time': 0.0011719089999999988, 'total_time': 0.315226785}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-8504293e-aa78-402d-8550-c2100ee4b712-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in la'}, 'id': 'call_d0gj', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in los angeles'}, 'id': 'call_fd1s', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1555, 'output_tokens': 67, 'total_tokens': 1622})]}}, 'step': 6, 'parents': {}}, created_at='2024-09-16T13:15:22.529964+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-a0f8-6870-8005-c9c6febda53f'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-a0f8-6870-8005-c9c6febda53f'}}, metadata={'source': 'loop', 'writes': None, 'step': 5, 'parents': {}}, created_at='2024-09-16T13:15:21.570500+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-a0f4-6b21-8004-b5c9a6d0f921'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742db-a0f4-6b21-8004-b5c9a6d0f921'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='What about in la?')]}}, 'step': 4, 'parents': {}}, created_at='2024-09-16T13:15:21.568919+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d9-0bd7-6d7b-8003-3315d8a00179'}}, tasks=(PregelTask(id='071038dc-016a-e6ee-c3b0-c945af37e034', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d9-0bd7-6d7b-8003-3315d8a00179'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in San Francisco is partly cloudy with a temperature of 13.9°C (57.0°F). The wind is blowing from the west at 10.7 mph (17.3 kph). The humidity is at 89%, and the pressure is 1009.0 hPa (29.78 in). For the next two weeks, the forecast shows mostly sunny conditions with temperatures ranging from 58°F to 76°F.', response_metadata={'token_usage': {'completion_tokens': 92, 'prompt_tokens': 1449, 'total_tokens': 1541, 'completion_time': 0.297921031, 'prompt_time': 0.148236813, 'queue_time': 0.01991232500000001, 'total_time': 0.446157844}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-b7dd39b8-0873-498a-9a1d-a51efbf347e8-0', usage_metadata={'input_tokens': 1449, 'output_tokens': 92, 'total_tokens': 1541})]}}, 'step': 3, 'parents': {}}, created_at='2024-09-16T13:14:12.246195+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d9-0192-66e6-8002-e7f347f13982'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d9-0192-66e6-8002-e7f347f13982'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492280, \'localtime\': \'2024-09-16 06:11\'}, \'current\': {\'last_updated_epoch\': 1726491600, \'last_updated\': \'2024-09-16 06:00\', \'temp_c\': 13.9, \'temp_f\': 57.0, \'is_day\': 0, \'condition\': {\'text\': \'Partly cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 10.7, \'wind_kph\': 17.3, \'wind_degree\': 273, \'wind_dir\': \'W\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.78, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 89, \'cloud\': 75, \'feelslike_c\': 12.5, \'feelslike_f\': 54.5, \'windchill_c\': 11.7, \'windchill_f\': 53.1, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.5, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 15.1, \'gust_kph\': 24.2}}"}, {\'url\': \'https://www.meteoprog.com/weather/Sanfrancisco/month/september/\', \'content\': \'San Francisco (United States) weather in September 2024 ☀️ Accurate weather forecast for San Francisco in September ⛅ Detailed forecast By month Current temperature "near me" Weather news ⊳ Widget of weather ⊳ Water temperature | METEOPROG\'}]', name='tavily_search_results_json', tool_call_id='call_nes8'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726492280, \'localtime\': \'2024-09-16 06:11\'}, \'current\': {\'last_updated_epoch\': 1726491600, \'last_updated\': \'2024-09-16 06:00\', \'temp_c\': 13.9, \'temp_f\': 57.0, \'is_day\': 0, \'condition\': {\'text\': \'Partly cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 10.7, \'wind_kph\': 17.3, \'wind_degree\': 273, \'wind_dir\': \'W\', \'pressure_mb\': 1009.0, \'pressure_in\': 29.78, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 89, \'cloud\': 75, \'feelslike_c\': 12.5, \'feelslike_f\': 54.5, \'windchill_c\': 11.7, \'windchill_f\': 53.1, \'heatindex_c\': 12.8, \'heatindex_f\': 55.1, \'dewpoint_c\': 12.0, \'dewpoint_f\': 53.5, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 1.0, \'gust_mph\': 15.1, \'gust_kph\': 24.2}}"}, {\'url\': \'https://www.timeanddate.com/weather/@z-us-94134/ext\', \'content\': \'Forecasted weather conditions the coming 2 weeks for San Francisco. Sign in. News. News Home; Astronomy News; Time Zone News ... 16 pm: Mon Sep 16: 68 / 59 °F ... 6:54 am: 7:11 pm: Thu Sep 19: 70 / 58 °F: Sunny. 76 °F: 8 mph: ↑: 58%: 3%-3 (Moderate) 6:55 am: 7:10 pm * Updated Thursday, September 5, 2024 2:23:50 am San Francisco time ...\'}]', name='tavily_search_results_json', tool_call_id='call_vvah')]}}, 'step': 2, 'parents': {}}, created_at='2024-09-16T13:14:11.169160+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-ad8a-6a60-8001-64bbe88a3c11'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-ad8a-6a60-8001-64bbe88a3c11'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_nes8', 'function': {'arguments': '{"query": "weather in sf"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_vvah', 'function': {'arguments': '{"query": "current weather in san francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 293, 'total_tokens': 360, 'completion_time': 0.210940495, 'prompt_time': 0.023038788, 'queue_time': 0.0008450519999999989, 'total_time': 0.233979283}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-169ae4a5-87d4-444a-9a22-699486b9bd18-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in sf'}, 'id': 'call_nes8', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in san francisco'}, 'id': 'call_vvah', 'type': 'tool_call'}], usage_metadata={'input_tokens': 293, 'output_tokens': 67, 'total_tokens': 360})]}}, 'step': 1, 'parents': {}}, created_at='2024-09-16T13:14:02.357973+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0eb-60e3-8000-80579993e005'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0eb-60e3-8000-80579993e005'}}, metadata={'source': 'loop', 'writes': None, 'step': 0, 'parents': {}}, created_at='2024-09-16T13:14:01.034331+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0e7-62a2-bfff-72afab277d42'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1ef742d8-a0e7-62a2-bfff-72afab277d42'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='What is the weather in sf?')]}}, 'step': -1, 'parents': {}}, created_at='2024-09-16T13:14:01.032759+00:00', parent_config=None, tasks=(PregelTask(id='58f2b54f-b867-f6d8-7396-52dd46d3524d', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))

# %% [markdown]
# ### Modify State
# Let's start by starting a fresh thread and running to clean out history.

# %%
thread2 = {"configurable": {"thread_id": str(2)}}
graph.invoke({"count":0, "scratch":"hi"},thread2)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %%
from IPython.display import Image

Image(graph.get_graph().draw_mermaid_png())

# %%
states2 = []
for state in graph.get_state_history(thread2):
    states2.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee1-6f8f-801f-d0dd517c2630'}} 4
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee0-6b47-801e-5b277b10c778'}} 3
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bedf-6714-801d-6cfeaecea10e'}} 2
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bedd-6f0c-801c-48ff2a695755'}} 1
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bedb-6f81-801b-da19646b3d80'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bed9-6d8a-801a-aadaacd009f4'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743fa-48a7-6b9f-8019-31ea49be1b97'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743fa-3b4c-672d-8018-8ccbd38f511b'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-fad7-6efd-8017-f05661bef444'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-f374-6811-8016-77a071fd9505'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-f36f-6c84-8015-fd7c1cac9b9b'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-7c1e-634d-8014-1ac37772e0f4'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-68ae-6a44-8013-e7365944349e'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-68ab-657d-8012-f328df01ed1e'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-a395-6461-8011-3026d17b7602'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-9987-6513-8010-bdd0aeb24aa0'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-219e-66a2-800f-4cf90c7c5d48'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-1941-6eb0-800e-0749d29f14a7'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-193e-6284-800d-7dcacd55a1dc'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-a7a1-694d-800c-4df910858858'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-a79e-6a61-800b-93ed4b85f88e'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-15b9-6900-800a-9d40808c39f1'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-1002-6370-8009-b423adfccd14'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-0fff-6ea2-8008-c9430d2d1d7c'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74356-093d-6a14-8007-664d971469ef'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74355-bc73-6c33-8006-8a09288072e6'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74355-bc69-6ea9-8005-b63a25580ed2'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434c-d269-66af-8004-97a6755ceaed'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434c-8f2c-65e1-8003-608e7aa41059'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434c-8f24-6cdf-8002-af712ffb3e4b'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-d335-67d1-8001-1f082dd4cf19'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-c838-661d-8000-d5788164c67b'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-c834-604f-bfff-7bcb030bfdb9'}} 0

# %% [markdown]
# Start by grabbing a state.

# %%
save_state = graph.get_state(states2[-3])
save_state
# Out:
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-d335-67d1-8001-1f082dd4cf19'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 291, 'total_tokens': 323, 'completion_time': 0.099687088, 'prompt_time': 0.020902289, 'queue_time': 0.0021976730000000007, 'total_time': 0.120589377}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-16ceb2b4-adcf-4940-88ca-f7d11d7bb3c3-0', usage_metadata={'input_tokens': 291, 'output_tokens': 32, 'total_tokens': 323})]}}, 'step': 1, 'parents': {}}, created_at='2024-09-16T13:16:20.525409+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-c838-661d-8000-d5788164c67b'}}, tasks=())

# %% [markdown]
# Now modify the values. One subtle item to note: Recall when agent state was defined, `count` used `operator.add` to indicate that values are *added* to the current value. Here, `-3` will be added to the current count value rather than replace it.

# %%
save_state.values["count"] = -3
save_state.values["scratch"] = "hello"
save_state
# Out:
# StateSnapshot(values={'count': -3, 'scratch': 'hello'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-d335-67d1-8001-1f082dd4cf19'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 291, 'total_tokens': 323, 'completion_time': 0.099687088, 'prompt_time': 0.020902289, 'queue_time': 0.0021976730000000007, 'total_time': 0.120589377}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-16ceb2b4-adcf-4940-88ca-f7d11d7bb3c3-0', usage_metadata={'input_tokens': 291, 'output_tokens': 32, 'total_tokens': 323})]}}, 'step': 1, 'parents': {}}, created_at='2024-09-16T13:16:20.525409+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-c838-661d-8000-d5788164c67b'}}, tasks=())

# %% [markdown]
# Now update the state. This creates a new entry at the *top*, or *latest* entry in memory. This will become the current state.

# %%
graph.update_state(thread2,save_state.values)
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1ef74408-2557-61c0-8020-9e5f9f7b4767'}}

# %% [markdown]
# Current state is at the top. You can match the `thread_ts`.
# Notice the `parent_config`, `thread_ts` of the new node - it is the previous node.

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-2557-61c0-8020-9e5f9f7b4767'}}, metadata={'source': 'update', 'step': 32, 'writes': {'Node2': {'count': -3, 'scratch': 'hello'}}, 'parents': {}}, created_at='2024-09-16T15:29:48.514117+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee1-6f8f-801f-d0dd517c2630'}}, tasks=(PregelTask(id='efec3492-5b65-19ce-90db-cc28edc122ce', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee1-6f8f-801f-d0dd517c2630'}}, metadata={'source': 'loop', 'writes': {'Node2': {'lnode': 'node_2', 'count': 1}}, 'step': 31, 'parents': {}}, created_at='2024-09-16T15:29:10.927134+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee0-6b47-801e-5b277b10c778'}}, tasks=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee0-6b47-801e-5b277b10c778'}}, metadata={'source': 'loop', 'writes': {'Node1': {'lnode': 'node_1', 'count': 1}}, 'step': 30, 'parents': {}}, created_at='2024-09-16T15:29:10.926614+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bedf-6714-801d-6cfeaecea10e'}}, tasks=(PregelTask(id='16fbeb6a-289a-3f49-e23c-8420b7bdb376', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None),))

# %% [markdown]
# ### Try again with `as_node`
# When writing using `update_state()`, you want to define to the graph logic which node should be assumed as the writer. What this does is allow th graph logic to find the node on the graph. After writing the values, the `next()` value is computed by travesing the graph using the new state. In this case, the state we have was written by `Node1`. The graph can then compute the next state as being `Node2`. Note that in some graphs, this may involve going through conditional edges!  Let's try this out.

# %%
graph.update_state(thread2,save_state.values, as_node="Node1")
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1ef74408-6da2-62cb-8021-15b7e2eabd9d'}}

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-6da2-62cb-8021-15b7e2eabd9d'}}, metadata={'source': 'update', 'step': 33, 'writes': {'Node1': {'count': -3, 'scratch': 'hello'}}, 'parents': {}}, created_at='2024-09-16T15:29:56.094614+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-2557-61c0-8020-9e5f9f7b4767'}}, tasks=(PregelTask(id='af644da5-9c3f-8dc7-1d37-5edb6accd3bd', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-2557-61c0-8020-9e5f9f7b4767'}}, metadata={'source': 'update', 'step': 32, 'writes': {'Node2': {'count': -3, 'scratch': 'hello'}}, 'parents': {}}, created_at='2024-09-16T15:29:48.514117+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee1-6f8f-801f-d0dd517c2630'}}, tasks=(PregelTask(id='efec3492-5b65-19ce-90db-cc28edc122ce', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee1-6f8f-801f-d0dd517c2630'}}, metadata={'source': 'loop', 'writes': {'Node2': {'lnode': 'node_2', 'count': 1}}, 'step': 31, 'parents': {}}, created_at='2024-09-16T15:29:10.927134+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee0-6b47-801e-5b277b10c778'}}, tasks=())

# %% [markdown]
# `invoke` will run from the current state if not given a particular `thread_ts`. This is now the entry that was just added.

# %%
graph.invoke(None,thread2)
# Out:
# node2, count:-2
# node1, count:-1
# node2, count:0
# node1, count:1
# node2, count:2
# {'lnode': 'node_2', 'scratch': 'hello', 'count': 3}

# %% [markdown]
# Print out the state history, notice the `scratch` value change on the latest entries.

# %%
for state in graph.get_state_history(thread2):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 3}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-8e81-65cb-8026-88d8bbcf3b4d'}}, metadata={'source': 'loop', 'writes': {'Node2': {'lnode': 'node_2', 'count': 1}}, 'step': 38, 'parents': {}}, created_at='2024-09-16T15:29:59.541487+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-8e80-6019-8025-e812dfd12961'}}, tasks=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-8e80-6019-8025-e812dfd12961'}}, metadata={'source': 'loop', 'writes': {'Node1': {'lnode': 'node_1', 'count': 1}}, 'step': 37, 'parents': {}}, created_at='2024-09-16T15:29:59.540922+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-8e7e-6a50-8024-4513e3909bf9'}}, tasks=(PregelTask(id='1c460cbe-540f-af15-d67d-2c532c448386', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-8e7e-6a50-8024-4513e3909bf9'}}, metadata={'source': 'loop', 'writes': {'Node2': {'lnode': 'node_2', 'count': 1}}, 'step': 36, 'parents': {}}, created_at='2024-09-16T15:29:59.540375+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-8e7d-6240-8023-bc6d4a6fd4ec'}}, tasks=(PregelTask(id='eee234ed-0159-c817-9966-2e7fc5aa65b1', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 0}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-8e7d-6240-8023-bc6d4a6fd4ec'}}, metadata={'source': 'loop', 'writes': {'Node1': {'lnode': 'node_1', 'count': 1}}, 'step': 35, 'parents': {}}, created_at='2024-09-16T15:29:59.539759+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-8e7b-6c40-8022-23534616e795'}}, tasks=(PregelTask(id='68a70aa2-814d-b54f-bcd8-bf90124cfae4', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': -1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-8e7b-6c40-8022-23534616e795'}}, metadata={'source': 'loop', 'writes': {'Node2': {'lnode': 'node_2', 'count': 1}}, 'step': 34, 'parents': {}}, created_at='2024-09-16T15:29:59.539195+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-6da2-62cb-8021-15b7e2eabd9d'}}, tasks=(PregelTask(id='c3b4c60d-8094-0c16-64e4-98f869b056df', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-6da2-62cb-8021-15b7e2eabd9d'}}, metadata={'source': 'update', 'step': 33, 'writes': {'Node1': {'count': -3, 'scratch': 'hello'}}, 'parents': {}}, created_at='2024-09-16T15:29:56.094614+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-2557-61c0-8020-9e5f9f7b4767'}}, tasks=(PregelTask(id='af644da5-9c3f-8dc7-1d37-5edb6accd3bd', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74408-2557-61c0-8020-9e5f9f7b4767'}}, metadata={'source': 'update', 'step': 32, 'writes': {'Node2': {'count': -3, 'scratch': 'hello'}}, 'parents': {}}, created_at='2024-09-16T15:29:48.514117+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee1-6f8f-801f-d0dd517c2630'}}, tasks=(PregelTask(id='efec3492-5b65-19ce-90db-cc28edc122ce', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee1-6f8f-801f-d0dd517c2630'}}, metadata={'source': 'loop', 'writes': {'Node2': {'lnode': 'node_2', 'count': 1}}, 'step': 31, 'parents': {}}, created_at='2024-09-16T15:29:10.927134+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee0-6b47-801e-5b277b10c778'}}, tasks=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bee0-6b47-801e-5b277b10c778'}}, metadata={'source': 'loop', 'writes': {'Node1': {'lnode': 'node_1', 'count': 1}}, 'step': 30, 'parents': {}}, created_at='2024-09-16T15:29:10.926614+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bedf-6714-801d-6cfeaecea10e'}}, tasks=(PregelTask(id='16fbeb6a-289a-3f49-e23c-8420b7bdb376', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bedf-6714-801d-6cfeaecea10e'}}, metadata={'source': 'loop', 'writes': {'Node2': {'lnode': 'node_2', 'count': 1}}, 'step': 29, 'parents': {}}, created_at='2024-09-16T15:29:10.926097+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bedd-6f0c-801c-48ff2a695755'}}, tasks=(PregelTask(id='a1796e35-f7e9-cfe0-6204-a63ef2cc6af8', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bedd-6f0c-801c-48ff2a695755'}}, metadata={'source': 'loop', 'writes': {'Node1': {'lnode': 'node_1', 'count': 1}}, 'step': 28, 'parents': {}}, created_at='2024-09-16T15:29:10.925483+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bedb-6f81-801b-da19646b3d80'}}, tasks=(PregelTask(id='365cc8d8-403f-682c-4f60-81f3cdd83b62', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bedb-6f81-801b-da19646b3d80'}}, metadata={'source': 'loop', 'writes': None, 'step': 27, 'parents': {}}, created_at='2024-09-16T15:29:10.924671+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bed9-6d8a-801a-aadaacd009f4'}}, tasks=(PregelTask(id='c50e5dae-5522-083a-7043-545b83ed88ae', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74406-bed9-6d8a-801a-aadaacd009f4'}}, metadata={'source': 'input', 'writes': {'__start__': {'count': 0, 'scratch': 'hi'}}, 'step': 26, 'parents': {}}, created_at='2024-09-16T15:29:10.923804+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743fa-48a7-6b9f-8019-31ea49be1b97'}}, tasks=(PregelTask(id='5c790cb5-963b-8c0d-528e-29c6244be7c9', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743fa-48a7-6b9f-8019-31ea49be1b97'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in Los Angeles is overcast with a temperature of 18.9°C (66.0°F). The wind is coming from the south at 6.9 mph (11.2 kph). The humidity is at 78%, and the pressure is 1012.0 hPa (29.87 in).', response_metadata={'token_usage': {'completion_tokens': 68, 'prompt_tokens': 2398, 'total_tokens': 2466, 'completion_time': 0.090666667, 'prompt_time': 0.495498891, 'queue_time': 0.004223464999999982, 'total_time': 0.586165558}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f66ccb39ec', 'finish_reason': 'stop', 'logprobs': None}, id='run-a81987c7-53b7-4cd0-9a79-279afdf300e9-0', usage_metadata={'input_tokens': 2398, 'output_tokens': 68, 'total_tokens': 2466})]}}, 'step': 25, 'parents': {}}, created_at='2024-09-16T15:23:36.407478+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743fa-3b4c-672d-8018-8ccbd38f511b'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743fa-3b4c-672d-8018-8ccbd38f511b'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726500193, \'localtime\': \'2024-09-16 08:23\'}, \'current\': {\'last_updated_epoch\': 1726499700, \'last_updated\': \'2024-09-16 08:15\', \'temp_c\': 18.9, \'temp_f\': 66.0, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 6.9, \'wind_kph\': 11.2, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1012.0, \'pressure_in\': 29.87, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 78, \'cloud\': 100, \'feelslike_c\': 18.9, \'feelslike_f\': 66.0, \'windchill_c\': 17.0, \'windchill_f\': 62.6, \'heatindex_c\': 17.0, \'heatindex_f\': 62.6, \'dewpoint_c\': 14.3, \'dewpoint_f\': 57.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.0, \'gust_kph\': 12.9}}"}, {\'url\': \'https://www.easeweather.com/north-america/united-states/california/los-angeles-county/los-angeles/september\', \'content\': \'September 2024 Weather - Los Angeles Weather in Los Angeles for September 2024 Your guide to Los Angeles weather in September - trends and predictions The forecast for the upcoming days in Los Angeles predicts a temperature of 33.4\\xa0°F, which is slightly above the historical average. In general, the average temperature in Los Angeles at the beginning of September is 33.7\\xa0°F. Los Angeles in September average weather Temperatures trend during September in Los Angeles Our weather forecast for Los Angeles in September is based on the analysis of historical data rather than real-time forecast models. Los Angeles in September - FAQ\'}]', name='tavily_search_results_json', id='c3abe209-a5d9-468d-901a-ec28af59a5ff', tool_call_id='call_smm9')]}}, 'step': 24, 'parents': {}}, created_at='2024-09-16T15:23:35.006993+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-fad7-6efd-8017-f05661bef444'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-fad7-6efd-8017-f05661bef444'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_smm9', 'function': {'arguments': '{"query": "Los Angeles weather today"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 1792, 'total_tokens': 1813, 'completion_time': 0.028, 'prompt_time': 0.38218156, 'queue_time': 0.002425978000000051, 'total_time': 0.41018156}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_9cb648b966', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-cbbcf09d-caae-475e-bd18-412e1091c1fa-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Los Angeles weather today'}, 'id': 'call_smm9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1792, 'output_tokens': 21, 'total_tokens': 1813})]}}, 'step': 23, 'parents': {}}, created_at='2024-09-16T15:23:28.248338+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-f374-6811-8016-77a071fd9505'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-f374-6811-8016-77a071fd9505'}}, metadata={'source': 'loop', 'writes': None, 'step': 22, 'parents': {}}, created_at='2024-09-16T15:23:27.473647+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-f36f-6c84-8015-fd7c1cac9b9b'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef743f9-f36f-6c84-8015-fd7c1cac9b9b'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in LA?')]}}, 'step': 21, 'parents': {}}, created_at='2024-09-16T15:23:27.471712+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-7c1e-634d-8014-1ac37772e0f4'}}, tasks=(PregelTask(id='aebbbdde-f8f5-2789-b024-fc06b9a34416', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-7c1e-634d-8014-1ac37772e0f4'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_06ct', 'function': {'arguments': '{"query":"weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_059f', 'function': {'arguments': '{"query":"current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 1746, 'total_tokens': 1809, 'completion_time': 0.199066478, 'prompt_time': 0.119821603, 'queue_time': 0.0009963060000000024, 'total_time': 0.318888081}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-b269afb5-4dd9-40ea-8522-bf26b65bc4a2-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_06ct', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_059f', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1746, 'output_tokens': 63, 'total_tokens': 1809})]}}, 'step': 20, 'parents': {}}, created_at='2024-09-16T14:39:24.292725+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-68ae-6a44-8013-e7365944349e'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-68ae-6a44-8013-e7365944349e'}}, metadata={'source': 'loop', 'writes': None, 'step': 19, 'parents': {}}, created_at='2024-09-16T14:39:22.254790+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-68ab-657d-8012-f328df01ed1e'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74397-68ab-657d-8012-f328df01ed1e'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in LA?')]}}, 'step': 18, 'parents': {}}, created_at='2024-09-16T14:39:22.253436+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-a395-6461-8011-3026d17b7602'}}, tasks=(PregelTask(id='c4258bd0-dd30-acd3-2d51-e1ff77847a08', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-a395-6461-8011-3026d17b7602'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='The current weather in Los Angeles is overcast with a temperature of 18.3°C (64.9°F). The wind is coming from the south at 7.2 mph (11.5 kph). The humidity is at 81%, and the pressure is 1011.0 hPa (29.86 in). There are no current hazards or advisories listed for the area.', response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 1650, 'total_tokens': 1731, 'completion_time': 0.256901755, 'prompt_time': 0.108699902, 'queue_time': 0.0012478669999999997, 'total_time': 0.365601657}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-46aaa3bb-7c93-47f8-acbe-8a0731f7e814-0', usage_metadata={'input_tokens': 1650, 'output_tokens': 81, 'total_tokens': 1731})]}}, 'step': 17, 'parents': {}}, created_at='2024-09-16T14:37:41.056806+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-9987-6513-8010-bdd0aeb24aa0'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-9987-6513-8010-bdd0aeb24aa0'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726497435, \'localtime\': \'2024-09-16 07:37\'}, \'current\': {\'last_updated_epoch\': 1726497000, \'last_updated\': \'2024-09-16 07:30\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.weathertab.com/en/c/e/09/united-states/california/los-angeles/\', \'content\': \'Explore comprehensive September 2024 weather forecasts for Los Angeles, including daily high and low temperatures, precipitation risks, and monthly temperature trends. Featuring detailed day-by-day forecasts, dynamic graphs of daily rain probabilities, and temperature trends to help you plan ahead. ... 16 84°F 55°F 29°C 13°C 06% 17 87°F 56 ...\'}]', name='tavily_search_results_json', id='8ae4b1d8-fb3a-43ba-9149-25f121b927e6', tool_call_id='call_0hx2'), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1726497435, \'localtime\': \'2024-09-16 07:37\'}, \'current\': {\'last_updated_epoch\': 1726497000, \'last_updated\': \'2024-09-16 07:30\', \'temp_c\': 18.3, \'temp_f\': 64.9, \'is_day\': 1, \'condition\': {\'text\': \'Overcast\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/122.png\', \'code\': 1009}, \'wind_mph\': 7.2, \'wind_kph\': 11.5, \'wind_degree\': 179, \'wind_dir\': \'S\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.86, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 100, \'feelslike_c\': 18.3, \'feelslike_f\': 64.9, \'windchill_c\': 16.8, \'windchill_f\': 62.3, \'heatindex_c\': 16.8, \'heatindex_f\': 62.3, \'dewpoint_c\': 13.9, \'dewpoint_f\': 57.0, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 4.0, \'gust_mph\': 8.4, \'gust_kph\': 13.5}}"}, {\'url\': \'https://www.weather.gov/lox/\', \'content\': \'Current Hazards. Daily Briefing; Latest Hazard Listing; Current Outlooks; ... Sep 16, 2024 at 2:04:08 am PDT Watches, Warnings & Advisories. Zoom Out. Gale Warning. Small Craft Advisory. Wind Advisory. ... National Weather Service Los Angeles, CA 520 North Elevar Street Oxnard, CA 93030 805-988-6610 Comments? Questions?\'}]', name='tavily_search_results_json', id='1a9f6801-2ac2-4c4a-be43-7770a8eefab7', tool_call_id='call_5j2e')]}}, 'step': 16, 'parents': {}}, created_at='2024-09-16T14:37:40.002471+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-219e-66a2-800f-4cf90c7c5d48'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-219e-66a2-800f-4cf90c7c5d48'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_0hx2', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_5j2e', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 512, 'total_tokens': 578, 'completion_time': 0.208016542, 'prompt_time': 0.035994171, 'queue_time': 0.000865651000000002, 'total_time': 0.244010713}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-652b8aea-0b51-4d0a-95cd-460571a836ab-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_0hx2', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_5j2e', 'type': 'tool_call'}], usage_metadata={'input_tokens': 512, 'output_tokens': 66, 'total_tokens': 578})]}}, 'step': 15, 'parents': {}}, created_at='2024-09-16T14:37:27.429073+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-1941-6eb0-800e-0749d29f14a7'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-1941-6eb0-800e-0749d29f14a7'}}, metadata={'source': 'loop', 'writes': None, 'step': 14, 'parents': {}}, created_at='2024-09-16T14:37:26.552317+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-193e-6284-800d-7dcacd55a1dc'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74393-193e-6284-800d-7dcacd55a1dc'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in LA?')]}}, 'step': 13, 'parents': {}}, created_at='2024-09-16T14:37:26.550776+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-a7a1-694d-800c-4df910858858'}}, tasks=(PregelTask(id='ae41b319-554a-8243-2811-e0cf1df8b23e', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-a7a1-694d-800c-4df910858858'}}, metadata={'source': 'loop', 'writes': None, 'step': 12, 'parents': {}}, created_at='2024-09-16T14:26:30.392642+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-a79e-6a61-800b-93ed4b85f88e'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7437a-a79e-6a61-800b-93ed4b85f88e'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in LA?')]}}, 'step': 11, 'parents': {}}, created_at='2024-09-16T14:26:30.391437+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-15b9-6900-800a-9d40808c39f1'}}, tasks=(PregelTask(id='10ac3814-b29e-1ece-9081-bdda2de49863', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-15b9-6900-800a-9d40808c39f1'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_s6dg', 'function': {'arguments': '{"query": "weather in LA"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_x8rc', 'function': {'arguments': '{"query": "current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 430, 'total_tokens': 496, 'completion_time': 0.207487056, 'prompt_time': 0.032166142, 'queue_time': 0.0008985879999999988, 'total_time': 0.239653198}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-83f2d5ea-e6c6-402e-9526-6248a83dfae2-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in LA'}, 'id': 'call_s6dg', 'type': 'tool_call'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_x8rc', 'type': 'tool_call'}], usage_metadata={'input_tokens': 430, 'output_tokens': 66, 'total_tokens': 496})]}}, 'step': 10, 'parents': {}}, created_at='2024-09-16T14:25:48.249666+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-1002-6370-8009-b423adfccd14'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-1002-6370-8009-b423adfccd14'}}, metadata={'source': 'loop', 'writes': None, 'step': 9, 'parents': {}}, created_at='2024-09-16T14:25:47.650329+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-0fff-6ea2-8008-c9430d2d1d7c'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74379-0fff-6ea2-8008-c9430d2d1d7c'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Whats the weather in LA?')]}}, 'step': 8, 'parents': {}}, created_at='2024-09-16T14:25:47.649384+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74356-093d-6a14-8007-664d971469ef'}}, tasks=(PregelTask(id='d15fe1fb-b3e1-a3f6-0e2f-8334a5d1ebbd', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74356-093d-6a14-8007-664d971469ef'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 383, 'total_tokens': 415, 'completion_time': 0.09948559, 'prompt_time': 0.026645538, 'queue_time': 0.0011054020000000019, 'total_time': 0.126131128}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b249a32-2fd6-48fe-bc60-906d85e1f99a-0', usage_metadata={'input_tokens': 383, 'output_tokens': 32, 'total_tokens': 415})]}}, 'step': 7, 'parents': {}}, created_at='2024-09-16T14:10:07.416565+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74355-bc73-6c33-8006-8a09288072e6'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74355-bc73-6c33-8006-8a09288072e6'}}, metadata={'source': 'loop', 'writes': None, 'step': 6, 'parents': {}}, created_at='2024-09-16T14:09:59.364647+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74355-bc69-6ea9-8005-b63a25580ed2'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef74355-bc69-6ea9-8005-b63a25580ed2'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Which one is warmer?')]}}, 'step': 5, 'parents': {}}, created_at='2024-09-16T14:09:59.360622+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434c-d269-66af-8004-97a6755ceaed'}}, tasks=(PregelTask(id='dce5e39f-77d4-7749-ccca-0a8dce1c31b4', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434c-d269-66af-8004-97a6755ceaed'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 337, 'total_tokens': 369, 'completion_time': 0.100450274, 'prompt_time': 0.026465486, 'queue_time': 0.0008678600000000015, 'total_time': 0.12691576}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-bfa5a169-f99a-4c2b-b4c1-6a17218b32ca-0', usage_metadata={'input_tokens': 337, 'output_tokens': 32, 'total_tokens': 369})]}}, 'step': 4, 'parents': {}}, created_at='2024-09-16T14:06:00.075381+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434c-8f2c-65e1-8003-608e7aa41059'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434c-8f2c-65e1-8003-608e7aa41059'}}, metadata={'source': 'loop', 'writes': None, 'step': 3, 'parents': {}}, created_at='2024-09-16T14:05:53.024897+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434c-8f24-6cdf-8002-af712ffb3e4b'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef7434c-8f24-6cdf-8002-af712ffb3e4b'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Which one is warmer?')]}}, 'step': 2, 'parents': {}}, created_at='2024-09-16T14:05:53.021812+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-d335-67d1-8001-1f082dd4cf19'}}, tasks=(PregelTask(id='d231721a-4740-f454-47ea-297016e51372', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-d335-67d1-8001-1f082dd4cf19'}}, metadata={'source': 'loop', 'writes': {'llm': {'messages': [AIMessage(content="I'm sorry but I do not have the capability to perform this task for you, I am happy to help you with any other queries you may have.", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 291, 'total_tokens': 323, 'completion_time': 0.099687088, 'prompt_time': 0.020902289, 'queue_time': 0.0021976730000000007, 'total_time': 0.120589377}, 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143', 'finish_reason': 'stop', 'logprobs': None}, id='run-16ceb2b4-adcf-4940-88ca-f7d11d7bb3c3-0', usage_metadata={'input_tokens': 291, 'output_tokens': 32, 'total_tokens': 323})]}}, 'step': 1, 'parents': {}}, created_at='2024-09-16T13:16:20.525409+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-c838-661d-8000-d5788164c67b'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-c838-661d-8000-d5788164c67b'}}, metadata={'source': 'loop', 'writes': None, 'step': 0, 'parents': {}}, created_at='2024-09-16T13:16:19.373185+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-c834-604f-bfff-7bcb030bfdb9'}}, tasks=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1ef742dd-c834-604f-bfff-7bcb030bfdb9'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='Which one is warmer?')]}}, 'step': -1, 'parents': {}}, created_at='2024-09-16T13:16:19.371412+00:00', parent_config=None, tasks=(PregelTask(id='8e0cce77-d765-7b2a-f6d7-b4e1a73acf9b', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))

# %% [markdown]
# Continue to experiment!
